# %% [markdown]
# # 〜スクレイピング〜

# %% [markdown]
# ### J-LEAGUE-DATA-SITE

# %% [markdown]
# 機械学習に使用するデータを集めていきます。
# Jリーグの公式HPから、試合日程、試合時の順位や得点数等をスクレイピングしていきます。
# https://data.j-league.or.jp/SFMS01/back

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages (4.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from IPython.display import Image
import time

# %% [markdown]
# まずは試合日程を取得します

# %%
team_id_list = ["14", "362", "269", "54", "270", "29", "271", "1", "94", "40", "35", "3", "27", "2", "11", "22", "4", "45", "21", "5", "34", "272", "6", "12", "273", "28", "46", "274", "78", "41", "275", "7", "13", "276", "347", "8", "39", "24", "9", "20", "18", "44", "42", "10", "330", "48", "36", "37", "369", "23", "43", "33", "47", "38", "31", "371", "338", "277", "339", "340", "341", "278"]
team_name_list = ["札幌", "八戸", "岩手", "仙台", "秋田", "山形", "福島", "鹿島", "水戸", "栃木", "群馬", "浦和", "大宮", "千葉", "柏", "FC東京", "東京Ｖ", "町田", "川崎Ｆ", "横浜FM", "横浜FC", "YS横浜", "横浜Ｆ", "湘南", "相模原", "甲府", "松本", "長野", "新潟", "富山", "金沢", "清水", "磐田", "藤枝", "沼津", "名古屋", "岐阜", "京都", "Ｇ大阪", "Ｃ大阪", "神戸", "鳥取", "岡山", "広島", "山口", "讃岐", "徳島", "愛媛", "今治", "福岡", "北九州", "鳥栖", "長崎", "熊本", "大分", "宮崎", "鹿児島", "琉球", "Ｆ東23", "Ｇ大23", "Ｃ大23", "J-22"]
url_head = "https://data.j-league.or.jp/SFMS01/search?team_ids="
url_foot = "&home_away_select=0&tv_relay_station_name="
df_result = None
for i in range(len(team_id_list)):
    
    url = url_head + team_id_list[i] + url_foot
    time.sleep(1) # スリープ処理
    j_data_list = pd.read_html(url)
    df_j_data = pd.DataFrame(j_data_list[0]) # データフレームに変換
    
    # チーム名のカラムを追加
    df_j_data["Team"] = team_name_list[i]
    
    df_result = pd.concat([df_result, df_j_data])

# %%
df_result
# Out:
#       年度           大会        節       試合日  K/O時刻  ホーム  スコア  アウェイ スタジアム  \
# 0   1997  ＹＮＣ 予選Ｂグループ   第１節第１日  03/08(土)  15:01  Ｇ大阪  3-3    札幌    万博
# 1   1997  ＹＮＣ 予選Ｂグループ   第２節第１日  03/15(土)  16:02   札幌  2-2   Ｖ川崎    長崎
# 2   1997  ＹＮＣ 予選Ｂグループ   第３節第１日  03/19(水)  19:01  横浜M  1-3    札幌   三ツ沢
# 3   1997  ＹＮＣ 予選Ｂグループ   第４節第１日  03/22(土)  15:00  Ｖ川崎  2-2    札幌   等々力
# 4   1997  ＹＮＣ 予選Ｂグループ   第５節第１日  03/26(水)  19:00   札幌  1-2   横浜M   長良川
# ..   ...          ...      ...       ...    ...  ...  ...   ...   ...
# 64  2015           Ｊ３  第３４節第２日  10/18(日)  13:05   富山  2-1  J-22    富山
# 65  2015           Ｊ３  第３５節第１日  10/25(日)  13:00   藤枝  1-4  J-22   エコパ
# 66  2015           Ｊ３  第３６節第２日  11/01(日)  13:04   長野  2-1  J-22   南長野
# 67  2015           Ｊ３  第３７節第１日  11/08(日)  13:00   福島  3-0  J-22  とうスタ
# 68  2015           Ｊ３  第３８節第２日  11/14(土)  12:04   山口  0-0  J-22  維新公園
#
#        入場者数 インターネット中継・TV放送  Team
# 0   10514.0            NaN    札幌
# 1    4823.0            NaN    札幌
# 2    5121.0            NaN    札幌
# 3    6940.0            NaN    札幌
# 4    2913.0            NaN    札幌
# ..      ...            ...   ...
# 64   2270.0            NaN  J-22
# 65    858.0            NaN  J-22
# 66   4163.0           信越放送  J-22
# 67    791.0            NaN  J-22
# 68   6322.0         山口朝日放送  J-22
#
# [45253 rows x 12 columns]

# %%
df_result.to_csv("match_schedule_original.csv")

# %% [markdown]
# 次に、試合時のチーム情報を取得します

# %%
import urllib.parse
from urllib.error import HTTPError
url1 = "https://data.j-league.or.jp/SFRT01/?competitionSectionIdLabel="
url2 = "&competitionIdLabel="

competitionIdLabel_j1 = ["明治安田生命Ｊ１リーグ",  "Ｊリーグ　ディビジョン１", "明治安田生命Ｊ１リーグ １ｓｔ","明治安田生命Ｊ１リーグ ２ｎｄ"]
competitionIdLabel_j2 = ["明治安田生命Ｊ２リーグ","Ｊリーグ　ディビジョン2",]
competitionIdLabel_j3 = ["明治安田生命Ｊ３リーグ"]
competitionId_j1 = ["477", "322", "397","398"]
competitionId_j2 = ["478", "323",]
competitionId_j3 = ["479"]
url3 = "&yearIdLabel="
url4 = "&yearId="
url5 = "&competitionId="
url6 = "&competitionSectionId="
url7 = "&search=search"
df_result = None
for year in range(2012, 2022):
    year_id = urllib.parse.quote(str(year)+"年")
    for section in range(1, 50):
        section_Id = urllib.parse.quote("第"+str(SectionId)+"節")
        is_ok_j1_1 = False
        is_ok_j1_2 = False
        is_ok_j2 = False
        is_ok_j3 = False
        print("処理中 :", year, section)
        # J1
        for i in range(len(competitionIdLabel_j1)):
            competition_Id = urllib.parse.quote(competitionIdLabel_j1[i], safe='　')
            competition_Id = competition_Id.replace(' ', '%E3%80%80')
            url_j1 = url1+section_Id+url2+competition_Id+url3+year_id+url4+str(year)+url5+competitionId_j1[i]+url6+str(section)+url7
            time.sleep(1) # スリープ処理
            try:
                data_list = pd.read_html(url_j1)
                df_data = pd.DataFrame(data_list[0]) # データフレームに変換
                df_data["year"] = year
                df_data["カテゴリ"] = "J1"
                df_data["節"] = section
                df_result = pd.concat([df_result, df_data])
                if competitionIdLabel_j1[i] == "明治安田生命Ｊ１リーグ １ｓｔ":
                    is_ok_j1_1 = True
                elif competitionIdLabel_j1[i] == "明治安田生命Ｊ１リーグ 2ｓｔ":
                    is_ok_j1_2 = True
                else:
                    is_ok_j1_1 = True
                    is_ok_j1_2 = True
            except HTTPError:
                continue
            
        # J2
        for i in range(len(competitionIdLabel_j2)):
            competition_Id = urllib.parse.quote(competitionIdLabel_j2[i])
            url_j2 = url1+section_Id+url2+competition_Id+url3+year_id+url4+str(year)+url5+competitionId_j2[i]+url6+str(section)+url7
            time.sleep(1) # スリープ処理
            try:
                data_list = pd.read_html(url_j2)
                df_data = pd.DataFrame(data_list[0]) # データフレームに変換
                df_data["year"] = year
                df_data["カテゴリ"] = "J2"
                df_data["節"] = section
                df_result = pd.concat([df_result, df_data])
                is_ok_j2 = True
            except HTTPError:
                continue
        
        # J3
        for i in range(len(competitionIdLabel_j3)):
            competition_Id = urllib.parse.quote(competitionIdLabel_j3[i])
            url_j3 = url1+section_Id+url2+competition_Id+url3+year_id+url4+str(year)+url5+competitionId_j3[i]+url6+str(section)+url7
            time.sleep(1) # スリープ処理
            try:
                data_list = pd.read_html(url_j3)
                df_data = pd.DataFrame(data_list[0]) # データフレームに変換
                df_data["year"] = year
                df_data["カテゴリ"] = "J3"
                df_data["節"] = section
                df_result = pd.concat([df_result, df_data])
                is_ok_j3 = True
            except HTTPError:
                continue
        
        if not(is_ok_j1_1 and is_ok_j1_2):
            print( "取得失敗　：　J1", year,  section, )
        if not(is_ok_j2):
            print( "取得失敗　：　J2", year,  section, )
        if not(is_ok_j3):
            print( "取得失敗　：　J3", year,  section, )
# Out:
# 処理中 : 2012 1
# 取得失敗　：　J3 2012 1
# 処理中 : 2012 2
# 取得失敗　：　J3 2012 2
# 処理中 : 2012 3
# 取得失敗　：　J3 2012 3
# 処理中 : 2012 4
# 取得失敗　：　J3 2012 4
# 処理中 : 2012 5
# 取得失敗　：　J3 2012 5
# 処理中 : 2012 6
# 取得失敗　：　J3 2012 6
# 処理中 : 2012 7
# 取得失敗　：　J3 2012 7
# 処理中 : 2012 8
# 取得失敗　：　J3 2012 8
# 処理中 : 2012 9
# 取得失敗　：　J3 2012 9
# 処理中 : 2012 10
# 取得失敗　：　J3 2012 10
# 処理中 : 2012 11
# 取得失敗　：　J3 2012 11
# 処理中 : 2012 12
# 取得失敗　：　J3 2012 12
# 処理中 : 2012 13
# 取得失敗　：　J3 2012 13
# 処理中 : 2012 14
# 取得失敗　：　J3 2012 14
# 処理中 : 2012 15
# 取得失敗　：　J3 2012 15
# 処理中 : 2012 16
# 取得失敗　：　J3 2012 16
# 処理中 : 2012 17
# 取得失敗　：　J3 2012 17
# 処理中 : 2012 18
# 取得失敗　：　J3 2012 18
# 処理中 : 2012 19
# 取得失敗　：　J3 2012 19
# 処理中 : 2012 20
# 取得失敗　：　J3 2012 20
# 処理中 : 2012 21
# 取得失敗　：　J3 2012 21
# 処理中 : 2012 22
# 取得失敗　：　J3 2012 22
# 処理中 : 2012 23
# 取得失敗　：　J3 2012 23
# 処理中 : 2012 24
# 取得失敗　：　J3 2012 24
# 処理中 : 2012 25
# 取得失敗　：　J3 2012 25
# 処理中 : 2012 26
# 取得失敗　：　J3 2012 26
# 処理中 : 2012 27
# 取得失敗　：　J3 2012 27
# 処理中 : 2012 28
# 取得失敗　：　J3 2012 28
# 処理中 : 2012 29
# 取得失敗　：　J3 2012 29
# 処理中 : 2012 30
# 取得失敗　：　J3 2012 30
# 処理中 : 2012 31
# 取得失敗　：　J3 2012 31
# 処理中 : 2012 32
# 取得失敗　：　J3 2012 32
# 処理中 : 2012 33
# 取得失敗　：　J3 2012 33
# 処理中 : 2012 34
# 取得失敗　：　J3 2012 34
# 処理中 : 2012 35
# 取得失敗　：　J1 2012 35
# 取得失敗　：　J3 2012 35
# 処理中 : 2012 36
# 取得失敗　：　J1 2012 36
# 取得失敗　：　J3 2012 36
# 処理中 : 2012 37
# 取得失敗　：　J1 2012 37
# 取得失敗　：　J3 2012 37
# 処理中 : 2012 38
# 取得失敗　：　J1 2012 38
# 取得失敗　：　J3 2012 38
# 処理中 : 2012 39
# 取得失敗　：　J1 2012 39
# 取得失敗　：　J3 2012 39
# 処理中 : 2012 40
# 取得失敗　：　J1 2012 40
# 取得失敗　：　J3 2012 40
# 処理中 : 2012 41
# 取得失敗　：　J1 2012 41
# 取得失敗　：　J3 2012 41
# 処理中 : 2012 42
# 取得失敗　：　J1 2012 42
# 取得失敗　：　J3 2012 42
# 処理中 : 2012 43
# 取得失敗　：　J1 2012 43
# 取得失敗　：　J2 2012 43
# 取得失敗　：　J3 2012 43
# 処理中 : 2012 44
# 取得失敗　：　J1 2012 44
# 取得失敗　：　J2 2012 44
# 取得失敗　：　J3 2012 44
# 処理中 : 2012 45
# 取得失敗　：　J1 2012 45
# 取得失敗　：　J2 2012 45
# 取得失敗　：　J3 2012 45
# 処理中 : 2012 46
# 取得失敗　：　J1 2012 46
# 取得失敗　：　J2 2012 46
# 取得失敗　：　J3 2012 46
# 処理中 : 2012 47
# 取得失敗　：　J1 2012 47
# 取得失敗　：　J2 2012 47
# 取得失敗　：　J3 2012 47
# 処理中 : 2012 48
# 取得失敗　：　J1 2012 48
# 取得失敗　：　J2 2012 48
# 取得失敗　：　J3 2012 48
# 処理中 : 2012 49
# 取得失敗　：　J1 2012 49
# 取得失敗　：　J2 2012 49
# 取得失敗　：　J3 2012 49
# 処理中 : 2013 1
# 取得失敗　：　J1 2013 1
# 取得失敗　：　J2 2013 1
# 取得失敗　：　J3 2013 1
# 処理中 : 2013 2
# 取得失敗　：　J1 2013 2
# 取得失敗　：　J2 2013 2
# 取得失敗　：　J3 2013 2
# 処理中 : 2013 3
# 取得失敗　：　J1 2013 3
# 取得失敗　：　J2 2013 3
# 取得失敗　：　J3 2013 3
# 処理中 : 2013 4
# 取得失敗　：　J1 2013 4
# 取得失敗　：　J2 2013 4
# 取得失敗　：　J3 2013 4
# 処理中 : 2013 5
# 取得失敗　：　J1 2013 5
# 取得失敗　：　J2 2013 5
# 取得失敗　：　J3 2013 5
# 処理中 : 2013 6
# 取得失敗　：　J1 2013 6
# 取得失敗　：　J2 2013 6
# 取得失敗　：　J3 2013 6
# 処理中 : 2013 7
# 取得失敗　：　J1 2013 7
# 取得失敗　：　J2 2013 7
# 取得失敗　：　J3 2013 7
# 処理中 : 2013 8
# 取得失敗　：　J1 2013 8
# 取得失敗　：　J2 2013 8
# 取得失敗　：　J3 2013 8
# 処理中 : 2013 9
# 取得失敗　：　J1 2013 9
# 取得失敗　：　J2 2013 9
# 取得失敗　：　J3 2013 9
# 処理中 : 2013 10
# 取得失敗　：　J1 2013 10
# 取得失敗　：　J2 2013 10
# 取得失敗　：　J3 2013 10
# 処理中 : 2013 11
# 取得失敗　：　J1 2013 11
# 取得失敗　：　J2 2013 11
# 取得失敗　：　J3 2013 11
# 処理中 : 2013 12
# 取得失敗　：　J1 2013 12
# 取得失敗　：　J2 2013 12
# 取得失敗　：　J3 2013 12
# 処理中 : 2013 13
# 取得失敗　：　J1 2013 13
# 取得失敗　：　J2 2013 13
# 取得失敗　：　J3 2013 13
# 処理中 : 2013 14
# 取得失敗　：　J1 2013 14
# 取得失敗　：　J2 2013 14
# 取得失敗　：　J3 2013 14
# 処理中 : 2013 15
# 取得失敗　：　J1 2013 15
# 取得失敗　：　J2 2013 15
# 取得失敗　：　J3 2013 15
# 処理中 : 2013 16
# 取得失敗　：　J1 2013 16
# 取得失敗　：　J2 2013 16
# 取得失敗　：　J3 2013 16
# 処理中 : 2013 17
# 取得失敗　：　J1 2013 17
# 取得失敗　：　J2 2013 17
# 取得失敗　：　J3 2013 17
# 処理中 : 2013 18
# 取得失敗　：　J1 2013 18
# 取得失敗　：　J2 2013 18
# 取得失敗　：　J3 2013 18
# 処理中 : 2013 19
# 取得失敗　：　J1 2013 19
# 取得失敗　：　J2 2013 19
# 取得失敗　：　J3 2013 19
# 処理中 : 2013 20
# 取得失敗　：　J1 2013 20
# 取得失敗　：　J2 2013 20
# 取得失敗　：　J3 2013 20
# 処理中 : 2013 21
# 取得失敗　：　J1 2013 21
# 取得失敗　：　J2 2013 21
# 取得失敗　：　J3 2013 21
# 処理中 : 2013 22
# 取得失敗　：　J1 2013 22
# 取得失敗　：　J2 2013 22
# 取得失敗　：　J3 2013 22
# 処理中 : 2013 23
# 取得失敗　：　J1 2013 23
# 取得失敗　：　J2 2013 23
# 取得失敗　：　J3 2013 23
# 処理中 : 2013 24
# 取得失敗　：　J1 2013 24
# 取得失敗　：　J2 2013 24
# 取得失敗　：　J3 2013 24
# 処理中 : 2013 25
# 取得失敗　：　J1 2013 25
# 取得失敗　：　J2 2013 25
# 取得失敗　：　J3 2013 25
# 処理中 : 2013 26
# 取得失敗　：　J1 2013 26
# 取得失敗　：　J2 2013 26
# 取得失敗　：　J3 2013 26
# 処理中 : 2013 27
# 取得失敗　：　J1 2013 27
# 取得失敗　：　J2 2013 27
# 取得失敗　：　J3 2013 27
# 処理中 : 2013 28
# 取得失敗　：　J1 2013 28
# 取得失敗　：　J2 2013 28
# 取得失敗　：　J3 2013 28
# 処理中 : 2013 29
# 取得失敗　：　J1 2013 29
# 取得失敗　：　J2 2013 29
# 取得失敗　：　J3 2013 29
# 処理中 : 2013 30
# 取得失敗　：　J1 2013 30
# 取得失敗　：　J2 2013 30
# 取得失敗　：　J3 2013 30
# 処理中 : 2013 31
# 取得失敗　：　J1 2013 31
# 取得失敗　：　J2 2013 31
# 取得失敗　：　J3 2013 31
# 処理中 : 2013 32
# 取得失敗　：　J1 2013 32
# 取得失敗　：　J2 2013 32
# 取得失敗　：　J3 2013 32
# 処理中 : 2013 33
# 取得失敗　：　J1 2013 33
# 取得失敗　：　J2 2013 33
# 取得失敗　：　J3 2013 33
# 処理中 : 2013 34
# 取得失敗　：　J1 2013 34
# 取得失敗　：　J2 2013 34
# 取得失敗　：　J3 2013 34
# 処理中 : 2013 35
# 取得失敗　：　J1 2013 35
# 取得失敗　：　J2 2013 35
# 取得失敗　：　J3 2013 35
# 処理中 : 2013 36
# 取得失敗　：　J1 2013 36
# 取得失敗　：　J2 2013 36
# 取得失敗　：　J3 2013 36
# 処理中 : 2013 37
# 取得失敗　：　J1 2013 37
# 取得失敗　：　J2 2013 37
# 取得失敗　：　J3 2013 37
# 処理中 : 2013 38
# 取得失敗　：　J1 2013 38
# 取得失敗　：　J2 2013 38
# 取得失敗　：　J3 2013 38
# 処理中 : 2013 39
# 取得失敗　：　J1 2013 39
# 取得失敗　：　J2 2013 39
# 取得失敗　：　J3 2013 39
# 処理中 : 2013 40
# 取得失敗　：　J1 2013 40
# 取得失敗　：　J2 2013 40
# 取得失敗　：　J3 2013 40
# 処理中 : 2013 41
# 取得失敗　：　J1 2013 41
# 取得失敗　：　J2 2013 41
# 取得失敗　：　J3 2013 41
# 処理中 : 2013 42
# 取得失敗　：　J1 2013 42
# 取得失敗　：　J2 2013 42
# 取得失敗　：　J3 2013 42
# 処理中 : 2013 43
# 取得失敗　：　J1 2013 43
# 取得失敗　：　J2 2013 43
# 取得失敗　：　J3 2013 43
# 処理中 : 2013 44
# 取得失敗　：　J1 2013 44
# 取得失敗　：　J2 2013 44
# 取得失敗　：　J3 2013 44
# 処理中 : 2013 45
# 取得失敗　：　J1 2013 45
# 取得失敗　：　J2 2013 45
# 取得失敗　：　J3 2013 45
# 処理中 : 2013 46
# 取得失敗　：　J1 2013 46
# 取得失敗　：　J2 2013 46
# 取得失敗　：　J3 2013 46
# 処理中 : 2013 47
# 取得失敗　：　J1 2013 47
# 取得失敗　：　J2 2013 47
# 取得失敗　：　J3 2013 47
# 処理中 : 2013 48
# 取得失敗　：　J1 2013 48
# 取得失敗　：　J2 2013 48
# 取得失敗　：　J3 2013 48
# 処理中 : 2013 49
# 取得失敗　：　J1 2013 49
# 取得失敗　：　J2 2013 49
# 取得失敗　：　J3 2013 49
# 処理中 : 2014 1
# 取得失敗　：　J1 2014 1
# 取得失敗　：　J2 2014 1
# 取得失敗　：　J3 2014 1
# 処理中 : 2014 2
# 取得失敗　：　J1 2014 2
# 取得失敗　：　J2 2014 2
# 取得失敗　：　J3 2014 2
# 処理中 : 2014 3
# 取得失敗　：　J1 2014 3
# 取得失敗　：　J2 2014 3
# 取得失敗　：　J3 2014 3
# 処理中 : 2014 4
# 取得失敗　：　J1 2014 4
# 取得失敗　：　J2 2014 4
# 取得失敗　：　J3 2014 4
# 処理中 : 2014 5
# 取得失敗　：　J1 2014 5
# 取得失敗　：　J2 2014 5
# 取得失敗　：　J3 2014 5
# 処理中 : 2014 6
# 取得失敗　：　J1 2014 6
# 取得失敗　：　J2 2014 6
# 取得失敗　：　J3 2014 6
# 処理中 : 2014 7
# 取得失敗　：　J1 2014 7
# 取得失敗　：　J2 2014 7
# 取得失敗　：　J3 2014 7
# 処理中 : 2014 8
# 取得失敗　：　J1 2014 8
# 取得失敗　：　J2 2014 8
# 取得失敗　：　J3 2014 8
# 処理中 : 2014 9
# 取得失敗　：　J1 2014 9
# 取得失敗　：　J2 2014 9
# 取得失敗　：　J3 2014 9
# 処理中 : 2014 10
# 取得失敗　：　J1 2014 10
# 取得失敗　：　J2 2014 10
# 取得失敗　：　J3 2014 10
# 処理中 : 2014 11
# 取得失敗　：　J1 2014 11
# 取得失敗　：　J2 2014 11
# 取得失敗　：　J3 2014 11
# 処理中 : 2014 12
# 取得失敗　：　J1 2014 12
# 取得失敗　：　J2 2014 12
# 取得失敗　：　J3 2014 12
# 処理中 : 2014 13
# 取得失敗　：　J1 2014 13
# 取得失敗　：　J2 2014 13
# 取得失敗　：　J3 2014 13
# 処理中 : 2014 14
# 取得失敗　：　J1 2014 14
# 取得失敗　：　J2 2014 14
# 取得失敗　：　J3 2014 14
# 処理中 : 2014 15
# 取得失敗　：　J1 2014 15
# 取得失敗　：　J2 2014 15
# 取得失敗　：　J3 2014 15
# 処理中 : 2014 16
# 取得失敗　：　J1 2014 16
# 取得失敗　：　J2 2014 16
# 取得失敗　：　J3 2014 16
# 処理中 : 2014 17
# 取得失敗　：　J1 2014 17
# 取得失敗　：　J2 2014 17
# 取得失敗　：　J3 2014 17
# 処理中 : 2014 18
# 取得失敗　：　J1 2014 18
# 取得失敗　：　J2 2014 18
# 取得失敗　：　J3 2014 18
# 処理中 : 2014 19
# 取得失敗　：　J1 2014 19
# 取得失敗　：　J2 2014 19
# 取得失敗　：　J3 2014 19
# 処理中 : 2014 20
# 取得失敗　：　J1 2014 20
# 取得失敗　：　J2 2014 20
# 取得失敗　：　J3 2014 20
# 処理中 : 2014 21
# 取得失敗　：　J1 2014 21
# 取得失敗　：　J2 2014 21
# 取得失敗　：　J3 2014 21
# 処理中 : 2014 22
# 取得失敗　：　J1 2014 22
# 取得失敗　：　J2 2014 22
# 取得失敗　：　J3 2014 22
# 処理中 : 2014 23
# 取得失敗　：　J1 2014 23
# 取得失敗　：　J2 2014 23
# 取得失敗　：　J3 2014 23
# 処理中 : 2014 24
# 取得失敗　：　J1 2014 24
# 取得失敗　：　J2 2014 24
# 取得失敗　：　J3 2014 24
# 処理中 : 2014 25
# 取得失敗　：　J1 2014 25
# 取得失敗　：　J2 2014 25
# 取得失敗　：　J3 2014 25
# 処理中 : 2014 26
# 取得失敗　：　J1 2014 26
# 取得失敗　：　J2 2014 26
# 取得失敗　：　J3 2014 26
# 処理中 : 2014 27
# 取得失敗　：　J1 2014 27
# 取得失敗　：　J2 2014 27
# 取得失敗　：　J3 2014 27
# 処理中 : 2014 28
# 取得失敗　：　J1 2014 28
# 取得失敗　：　J2 2014 28
# 取得失敗　：　J3 2014 28
# 処理中 : 2014 29
# 取得失敗　：　J1 2014 29
# 取得失敗　：　J2 2014 29
# 取得失敗　：　J3 2014 29
# 処理中 : 2014 30
# 取得失敗　：　J1 2014 30
# 取得失敗　：　J2 2014 30
# 取得失敗　：　J3 2014 30
# 処理中 : 2014 31
# 取得失敗　：　J1 2014 31
# 取得失敗　：　J2 2014 31
# 取得失敗　：　J3 2014 31
# 処理中 : 2014 32
# 取得失敗　：　J1 2014 32
# 取得失敗　：　J2 2014 32
# 取得失敗　：　J3 2014 32
# 処理中 : 2014 33
# 取得失敗　：　J1 2014 33
# 取得失敗　：　J2 2014 33
# 取得失敗　：　J3 2014 33
# 処理中 : 2014 34
# 取得失敗　：　J1 2014 34
# 取得失敗　：　J2 2014 34
# 取得失敗　：　J3 2014 34
# 処理中 : 2014 35
# 取得失敗　：　J1 2014 35
# 取得失敗　：　J2 2014 35
# 取得失敗　：　J3 2014 35
# 処理中 : 2014 36
# 取得失敗　：　J1 2014 36
# 取得失敗　：　J2 2014 36
# 取得失敗　：　J3 2014 36
# 処理中 : 2014 37
# 取得失敗　：　J1 2014 37
# 取得失敗　：　J2 2014 37
# 取得失敗　：　J3 2014 37
# 処理中 : 2014 38
# 取得失敗　：　J1 2014 38
# 取得失敗　：　J2 2014 38
# 取得失敗　：　J3 2014 38
# 処理中 : 2014 39
# 取得失敗　：　J1 2014 39
# 取得失敗　：　J2 2014 39
# 取得失敗　：　J3 2014 39
# 処理中 : 2014 40
# 取得失敗　：　J1 2014 40
# 取得失敗　：　J2 2014 40
# 取得失敗　：　J3 2014 40
# 処理中 : 2014 41
# 取得失敗　：　J1 2014 41
# 取得失敗　：　J2 2014 41
# 取得失敗　：　J3 2014 41
# 処理中 : 2014 42
# 取得失敗　：　J1 2014 42
# 取得失敗　：　J2 2014 42
# 取得失敗　：　J3 2014 42
# 処理中 : 2014 43
# 取得失敗　：　J1 2014 43
# 取得失敗　：　J2 2014 43
# 取得失敗　：　J3 2014 43
# 処理中 : 2014 44
# 取得失敗　：　J1 2014 44
# 取得失敗　：　J2 2014 44
# 取得失敗　：　J3 2014 44
# 処理中 : 2014 45
# 取得失敗　：　J1 2014 45
# 取得失敗　：　J2 2014 45
# 取得失敗　：　J3 2014 45
# 処理中 : 2014 46
# 取得失敗　：　J1 2014 46
# 取得失敗　：　J2 2014 46
# 取得失敗　：　J3 2014 46
# 処理中 : 2014 47
# 取得失敗　：　J1 2014 47
# 取得失敗　：　J2 2014 47
# 取得失敗　：　J3 2014 47
# 処理中 : 2014 48
# 取得失敗　：　J1 2014 48
# 取得失敗　：　J2 2014 48
# 取得失敗　：　J3 2014 48
# 処理中 : 2014 49
# 取得失敗　：　J1 2014 49
# 取得失敗　：　J2 2014 49
# 取得失敗　：　J3 2014 49
# 処理中 : 2015 1
# 取得失敗　：　J2 2015 1
# 取得失敗　：　J3 2015 1
# 処理中 : 2015 2
# 取得失敗　：　J2 2015 2
# 取得失敗　：　J3 2015 2
# 処理中 : 2015 3
# 取得失敗　：　J2 2015 3
# 取得失敗　：　J3 2015 3
# 処理中 : 2015 4
# 取得失敗　：　J2 2015 4
# 取得失敗　：　J3 2015 4
# 処理中 : 2015 5
# 取得失敗　：　J2 2015 5
# 取得失敗　：　J3 2015 5
# 処理中 : 2015 6
# 取得失敗　：　J2 2015 6
# 取得失敗　：　J3 2015 6
# 処理中 : 2015 7
# 取得失敗　：　J2 2015 7
# 取得失敗　：　J3 2015 7
# 処理中 : 2015 8
# 取得失敗　：　J2 2015 8
# 取得失敗　：　J3 2015 8
# 処理中 : 2015 9
# 取得失敗　：　J2 2015 9
# 取得失敗　：　J3 2015 9
# 処理中 : 2015 10
# 取得失敗　：　J2 2015 10
# 取得失敗　：　J3 2015 10
# 処理中 : 2015 11
# 取得失敗　：　J2 2015 11
# 取得失敗　：　J3 2015 11
# 処理中 : 2015 12
# 取得失敗　：　J2 2015 12
# 取得失敗　：　J3 2015 12
# 処理中 : 2015 13
# 取得失敗　：　J2 2015 13
# 取得失敗　：　J3 2015 13
# 処理中 : 2015 14
# 取得失敗　：　J2 2015 14
# 取得失敗　：　J3 2015 14
# 処理中 : 2015 15
# 取得失敗　：　J2 2015 15
# 取得失敗　：　J3 2015 15
# 処理中 : 2015 16
# 取得失敗　：　J2 2015 16
# 取得失敗　：　J3 2015 16
# 処理中 : 2015 17
# 取得失敗　：　J2 2015 17
# 取得失敗　：　J3 2015 17
# 処理中 : 2015 18
# 取得失敗　：　J1 2015 18
# 取得失敗　：　J2 2015 18
# 取得失敗　：　J3 2015 18
# 処理中 : 2015 19
# 取得失敗　：　J1 2015 19
# 取得失敗　：　J2 2015 19
# 取得失敗　：　J3 2015 19
# 処理中 : 2015 20
# 取得失敗　：　J1 2015 20
# 取得失敗　：　J2 2015 20
# 取得失敗　：　J3 2015 20
# 処理中 : 2015 21
# 取得失敗　：　J1 2015 21
# 取得失敗　：　J2 2015 21
# 取得失敗　：　J3 2015 21
# 処理中 : 2015 22
# 取得失敗　：　J1 2015 22
# 取得失敗　：　J2 2015 22
# 取得失敗　：　J3 2015 22
# 処理中 : 2015 23
# 取得失敗　：　J1 2015 23
# 取得失敗　：　J2 2015 23
# 取得失敗　：　J3 2015 23
# 処理中 : 2015 24
# 取得失敗　：　J1 2015 24
# 取得失敗　：　J2 2015 24
# 取得失敗　：　J3 2015 24
# 処理中 : 2015 25
# 取得失敗　：　J1 2015 25
# 取得失敗　：　J2 2015 25
# 取得失敗　：　J3 2015 25
# 処理中 : 2015 26
# 取得失敗　：　J1 2015 26
# 取得失敗　：　J2 2015 26
# 取得失敗　：　J3 2015 26
# 処理中 : 2015 27
# 取得失敗　：　J1 2015 27
# 取得失敗　：　J2 2015 27
# 取得失敗　：　J3 2015 27
# 処理中 : 2015 28
# 取得失敗　：　J1 2015 28
# 取得失敗　：　J2 2015 28
# 取得失敗　：　J3 2015 28
# 処理中 : 2015 29
# 取得失敗　：　J1 2015 29
# 取得失敗　：　J2 2015 29
# 取得失敗　：　J3 2015 29
# 処理中 : 2015 30
# 取得失敗　：　J1 2015 30
# 取得失敗　：　J2 2015 30
# 取得失敗　：　J3 2015 30
# 処理中 : 2015 31
# 取得失敗　：　J1 2015 31
# 取得失敗　：　J2 2015 31
# 取得失敗　：　J3 2015 31
# 処理中 : 2015 32
# 取得失敗　：　J1 2015 32
# 取得失敗　：　J2 2015 32
# 取得失敗　：　J3 2015 32
# 処理中 : 2015 33
# 取得失敗　：　J1 2015 33
# 取得失敗　：　J2 2015 33
# 取得失敗　：　J3 2015 33
# 処理中 : 2015 34
# 取得失敗　：　J1 2015 34
# 取得失敗　：　J2 2015 34
# 取得失敗　：　J3 2015 34
# 処理中 : 2015 35
# 取得失敗　：　J1 2015 35
# 取得失敗　：　J2 2015 35
# 取得失敗　：　J3 2015 35
# 処理中 : 2015 36
# 取得失敗　：　J1 2015 36
# 取得失敗　：　J2 2015 36
# 取得失敗　：　J3 2015 36
# 処理中 : 2015 37
# 取得失敗　：　J1 2015 37
# 取得失敗　：　J2 2015 37
# 取得失敗　：　J3 2015 37
# 処理中 : 2015 38
# 取得失敗　：　J1 2015 38
# 取得失敗　：　J2 2015 38
# 取得失敗　：　J3 2015 38
# 処理中 : 2015 39
# 取得失敗　：　J1 2015 39
# 取得失敗　：　J2 2015 39
# 取得失敗　：　J3 2015 39
# 処理中 : 2015 40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-1c317af02cc4> in <module>
#      29             competition_Id = urllib.parse.quote(competitionIdLabel_j1[i])
#      30             url_j1 = url1+section_Id+url2+competition_Id+url3+year_id+url4+str(year)+url5+competitionId_j1[i]+url6+str(section)+url7
# ---> 31             time.sleep(1) # スリープ処理
#      32             try:
#      33                 data_list = pd.read_html(url_j1)
#
# KeyboardInterrupt:

# %%
df_result
