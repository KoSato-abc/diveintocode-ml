# %%
import time

# %%
# ipynb用のimport処理
import ipynb_import_lib
common = ipynb_import_lib.import_ipynb("codes/common/common.ipynb")
scraping_all = ipynb_import_lib.import_ipynb("codes/scraping/scraping_all.ipynb")

# %%
sa = scraping_all.scraping_all()

# %%
start = time.time()

sa.scraping_and_clean(True)

e_time = time.time() - start
print ("e_time:{0}".format(e_time) + "[s]")
# Out:
# _scraping_info : 北海道コンサドーレ札幌 2012 url= https://www.football-lab.jp/sapp/match/?year=2012 ( 1 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2013 url= https://www.football-lab.jp/sapp/match/?year=2013 ( 2 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2014 url= https://www.football-lab.jp/sapp/match/?year=2014 ( 3 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2015 url= https://www.football-lab.jp/sapp/match/?year=2015 ( 4 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2016 url= https://www.football-lab.jp/sapp/match/?year=2016 ( 5 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2017 url= https://www.football-lab.jp/sapp/match/?year=2017 ( 6 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2018 url= https://www.football-lab.jp/sapp/match/?year=2018 ( 7 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2019 url= https://www.football-lab.jp/sapp/match/?year=2019 ( 8 / 610 )
# _scraping_info : 北海道コンサドーレ札幌 2020 url= https://www.football-lab.jp/sapp/match/?year=2020 ( 9 / 610 )
# ...

# %%
start = time.time()

df_info2, df_stat2 = s.scraping(True)

e_time = time.time() - start
print ("e_time:{0}".format(e_time) + "[s]")
# Out:
# _scraping_info : 北海道コンサドーレ札幌 2021 url= https://www.football-lab.jp/sapp/match/?year=2021 ( 10 / 610 )
# _scraping_info : ベガルタ仙台 2021 url= https://www.football-lab.jp/send/match/?year=2021 ( 20 / 610 )
# _scraping_info : 鹿島アントラーズ 2021 url= https://www.football-lab.jp/kasm/match/?year=2021 ( 30 / 610 )
# _scraping_info : 浦和レッズ 2021 url= https://www.football-lab.jp/uraw/match/?year=2021 ( 40 / 610 )
# _scraping_info : 柏レイソル 2021 url= https://www.football-lab.jp/kasw/match/?year=2021 ( 50 / 610 )
# _scraping_info : ＦＣ東京 2021 url= https://www.football-lab.jp/fctk/match/?year=2021 ( 60 / 610 )
# _scraping_info : 川崎フロンターレ 2021 url= https://www.football-lab.jp/ka-f/match/?year=2021 ( 70 / 610 )
# _scraping_info : 横浜Ｆ・マリノス 2021 url= https://www.football-lab.jp/y-fm/match/?year=2021 ( 80 / 610 )
# _scraping_info : 横浜ＦＣ 2021 url= https://www.football-lab.jp/y-fc/match/?year=2021 ( 90 / 610 )
# _scraping_info : 湘南ベルマーレ 2021 url= https://www.football-lab.jp/shon/match/?year=2021 ( 100 / 610 )
# ...

# %%
start = time.time()

df_match_schedule_1, j_rank_table_1, j_rank_table_has_stage_1 = j.scraping(False)

e_time = time.time() - start
print ("e_time:{0}".format(e_time) + "[s]")
# Out:
# 処理中 : 2012 1
# 処理中 : 2012 2
