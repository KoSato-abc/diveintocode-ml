# %%
cd ..
# Out:
# /Users/satouwataru/Desktop/DiveIntoCode/git/diveintocode-ml/GraduationWork/v1/codes/model

# %%
cd ..
# Out:
# /Users/satouwataru/Desktop/DiveIntoCode/git/diveintocode-ml/GraduationWork/v1/codes

# %%
cd ..
# Out:
# /Users/satouwataru/Desktop/DiveIntoCode/git/diveintocode-ml/GraduationWork/v1

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import optuna.integration.lightgbm as lgb_o
from sklearn.metrics import mean_squared_error
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %%
def preprocessing():
    df = pd.read_csv('data/marge/marge.csv', index_col=0).reset_index(drop = True)
    M_TEAM_NAMES = pd.read_csv('data/other/TEAM_NAMES.csv').values.tolist()
    M_COACH_LIST = pd.read_csv('data/other/COACH_LIST.csv').columns.tolist()
    
    #     df = df[df['年月日'] < yyyyMMdd]
    df = df.dropna().reset_index(drop = True)
    
    # ○○、○○成功率　をまとめる
    h_a = ['H_', 'A_']
    par_calumns = ['パス', 'クロス', 'スローイン', 'ドリブル', 'タックル']
    for head in h_a:
        for col in par_calumns:
            df[head+'成功した'+col] = df[head + col] * df[head + col + '成功率']/100
            df[head+'失敗した'+col] = df[head + col] - df[head+'成功した'+col]
            df.drop(columns = [head + col], inplace = True)
            df.drop(columns = [head + col + '成功率'], inplace = True)
    
    hour_list = []
    for i, row in df.iterrows():
        hour_list += [row['キックオフ時刻'][:2]]
    df_tmp = pd.DataFrame(hour_list, columns = ['キックオフ時'])
    df = pd.concat([df, df_tmp],axis=1)
    df.drop(columns = ['キックオフ時刻'], inplace = True)
    
    hare_list, ame_list, kumori_list, okunai_list = [], [], [], []
    j1_list, j2_list, j3_list = [], [], []
    h_df_list, h_mf_list, h_fw_list = [], [], []
    a_df_list, a_mf_list, a_fw_list = [], [], []
    h_rank_list, a_rank_list = [], []
    for i, row in df.iterrows():
        whether = row['天候']
        category = row['カテゴリ']

        H_positions = ''
        A_positions = ''
        for i in range(1, 12):
            H_positions += row['H_ポジション' + str(i)]
            A_positions += row['A_ポジション' + str(i)]

        h_df_list += [H_positions.count('DF')]
        h_mf_list += [H_positions.count('MF')]
        h_fw_list += [H_positions.count('FW')]
        a_df_list += [A_positions.count('DF')]
        a_mf_list += [A_positions.count('MF')]
        a_fw_list += [A_positions.count('FW')]
        
        h_rank_list += [str(row['H_順位']).replace('※', '')]
        a_rank_list += [str(row['A_順位']).replace('※', '')]
        
        if category == 'J1':
            j1_list += [1]
            j2_list += [0]
            j3_list += [0]
        elif category == 'J2':
            j1_list += [0]
            j2_list += [1]
            j3_list += [0]
        else:
            j1_list += [0]
            j2_list += [0]
            j3_list += [1]

        if 0 < whether.count('晴'):
            hare_list += [1]
        else:
            hare_list += [0]
        if 0 < whether.count('雨'):
            ame_list += [1]
        else:
            ame_list += [0]
        if 0 < whether.count('曇'):
            kumori_list += [1]
        else:
            kumori_list += [0]
        if 0 < whether.count('室内'):
            okunai_list += [1]
        else:
            okunai_list += [0]

    df_tmp1 = pd.DataFrame(hare_list, columns = ['晴_flg'])
    df_tmp2 = pd.DataFrame(ame_list, columns = ['雨_flg'])
    df_tmp3 = pd.DataFrame(kumori_list, columns = ['曇_flg'])
    df_tmp4 = pd.DataFrame(okunai_list, columns = ['室内_flg'])
    df_tmp5 = pd.DataFrame(j1_list, columns = ['J1_flg'])
    df_tmp6 = pd.DataFrame(j2_list, columns = ['J2_flg'])
    df_tmp7 = pd.DataFrame(j3_list, columns = ['J3_flg'])
    df_tmp8 = pd.DataFrame(h_df_list, columns = ['H_DF'])
    df_tmp9 = pd.DataFrame(h_mf_list, columns = ['H_MF'])
    df_tmp10 = pd.DataFrame(h_fw_list, columns = ['H_FW'])
    df_tmp11 = pd.DataFrame(a_df_list, columns = ['A_DF'])
    df_tmp12 = pd.DataFrame(a_mf_list, columns = ['A_MF'])
    df_tmp13 = pd.DataFrame(a_fw_list, columns = ['A_FW'])
    df_tmp14 = pd.DataFrame(h_rank_list, columns = ['H_順位'])
    df_tmp15 = pd.DataFrame(a_rank_list, columns = ['A_順位'])
    
    df = pd.concat([df, df_tmp1, df_tmp2, df_tmp3, df_tmp4, df_tmp5, df_tmp6, df_tmp7, df_tmp8, df_tmp9, df_tmp10, df_tmp11, df_tmp12, df_tmp13, df_tmp14, df_tmp15],axis=1)

    drop_colmuns = []
    for i in range(1, 12):
        drop_colmuns += ['H_ポジション' + str(i)]
        drop_colmuns += ['A_ポジション' + str(i)]
        drop_colmuns += ['H_選手' + str(i)]
        drop_colmuns += ['A_選手' + str(i)]
        
    df = team_to_index(df, 'H_Team')
    df = team_to_index(df, 'A_Team')
    df = coach_to_index(df)
    
    df.drop(columns = ['天候', 'カテゴリ', 'H_順位', 'A_順位'] + drop_colmuns, inplace = True)
    df.drop(columns = ['スタジアム', '入場者数', '気温', '湿度', '晴_flg', '雨_flg', '曇_flg', '室内_flg', 'キックオフ時'], inplace = True)
    
#     df1 = df['train_test']
#     df.drop(columns = ['train_test'], inplace = True)
    df = df.astype('float64')
#     df = pd.concat([df, df1], axis = 1)
    
    category_columns = ['H_Team', 'A_Team', 'H_監督', 'A_監督']
    for column in category_columns:
        df[column] = pd.Series(df[column]).astype('category')
        
#     df.to_csv("data/model/preprocessing.csv")
    
    return df

def team_to_index(df, tar_col):
    
    M_TEAM_NAMES = pd.read_csv('data/other/TEAM_NAMES.csv').values.tolist()
    
    df = df.copy()
    m_team_list = []
    for i, team_list in enumerate(M_TEAM_NAMES):
        m_team_list += [team_list[0]]

    team_list = []
    for i, row in df.iterrows():
        team_list += [m_team_list.index(row[tar_col])]
    df_tmp = pd.DataFrame(team_list, columns = [tar_col])
    df.drop(columns = [tar_col], inplace=True)
    df = pd.concat([df, df_tmp], axis=1)
    
    return df

def coach_to_index(df):
    M_COACH_LIST = pd.read_csv('data/other/COACH_LIST.csv', index_col=0).reset_index(drop = True).T.values[0].tolist()
    
    for i, row in df.iterrows():
        try:
            M_COACH_LIST.index(row['H_監督'])
        except ValueError:
            M_COACH_LIST += [row['H_監督']]
        try:
            M_COACH_LIST.index(row['A_監督'])
        except ValueError:
            M_COACH_LIST += [row['A_監督']]
    df_corch = pd.DataFrame(M_COACH_LIST, columns = ['監督名'])
#     df_corch.to_csv("data/other/COACH_LIST.csv")
    
    df = df.copy()
    h_coach_list = []
    a_coach_list = []
    for i, row in df.iterrows():
        h_coach_list += [M_COACH_LIST.index(row['H_監督'])]
        a_coach_list += [M_COACH_LIST.index(row['A_監督'])]
            
    df.drop(columns = ['H_監督', 'A_監督'], inplace=True)
    df_tmp1 = pd.DataFrame(h_coach_list, columns = ['H_監督'])
    df_tmp2 = pd.DataFrame(a_coach_list, columns = ['A_監督'])
    df = pd.concat([df, df_tmp1, df_tmp2], axis=1)
    
    return df

# %%
def get_y_pred(y_pred_, y_test):
    
    best_accuracy = 0
    thresholds = np.arange(0, 4, 0.01)
    best_threshold = 0
    y_pred = []
    for threshold in thresholds:
        y_pred_tmp = []
        for y in y_pred_:
            if abs(y)<threshold:
                y_pred_tmp += [0]
            elif y > 0:
                y_pred_tmp += [1]
            else:
                y_pred_tmp += [2]
                
        accuracy = sum(y_test == y_pred_tmp) / len(y_test)
        
        if best_accuracy < accuracy:
            best_accuracy = accuracy
            y_pred = y_pred_tmp
            best_threshold = threshold
    
    return np.array(y_pred), best_threshold

# %%
def fit_reg(x_train, x_val, x_test, y_train, y_val, y_test):

        lgb_train = lgb_o.Dataset(x_train, y_train)
        lgb_eval = lgb_o.Dataset(x_val, y_val) 
        # LightGBM parameters
        params = {
            'objective': 'regression', # 回帰  
            'metric': 'rmse', # rsme(平均二乗誤差の平方根) 
        }
        # モデルの学習
        model = lgb_o.train(params,
                          train_set=lgb_train,
                          valid_sets=lgb_eval,
                          early_stopping_rounds=100,
                          verbose_eval=200,
                          )
        
        # テストデータの予測
        y_pred = model.predict(x_test, num_iteration=model.best_iteration)
        # rmse : 平均二乗誤差の平方根
        mse = mean_squared_error(y_test, y_pred) # MSE(平均二乗誤差)の算出
        rmse = np.sqrt(mse) # RSME = √MSEの算出
        print('goal_deff rmse : ', rmse)
        
        return y_pred

# %%
from sklearn import metrics

def fit_binary(x_train, x_val, x_test, y_train, y_val, y_test):

        lgb_train = lgb_o.Dataset(x_train, y_train)
        lgb_eval = lgb_o.Dataset(x_val, y_val) 
        # 学習用パラメータ
        lgbm_params = {
            'objective': 'multiclass',
            'metric': 'multi_logloss',
            'num_class': 2,
        }
        # 学習
        gbm_o = lgb_o.train(lgbm_params,
                        lgb_train,
                        valid_sets=lgb_eval,
                        early_stopping_rounds=100,
                        verbose_eval=200,)

        y_pred_proba = gbm_o.predict(x_test, num_iteration=gbm_o.best_iteration)
        y_pred = np.argmax(y_pred_proba, axis=1)
        
        # Accuracy の計算
        accuracy = sum(y_test == y_pred) / len(y_test)
        print('accuracy:', accuracy)
        
        return y_pred, y_pred_proba

# %%
y_columns = ['H_goal', 'A_goal', 'goal_difference', 'H_result']
df = preprocessing()
# Out:
# /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (13,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
train, val = train_test_split(df, train_size=0.75)
val, test = train_test_split(val, train_size=0.75)

y_train = train['goal_difference']
x_train = train.drop(columns = y_columns)
y_val = val['goal_difference']
x_val = val.drop(columns = y_columns)
y_test = test['goal_difference']
x_test = test.drop(columns = y_columns)

# %%
y_pred = fit_reg(x_train, x_val, x_test, y_train, y_val, y_test)
# Out:
# [I 2021-05-09 14:54:59,239] A new study created in memory with name: no-name-9cb9ffd1-7fe9-4978-b9ba-adebfd8698bd
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]/Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002424 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  14%|#4        | 1/7 [00:00<00:03,  1.91it/s][I 2021-05-09 14:54:59,776] Trial 0 finished with value: 1.185628584273061 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  14%|#4        | 1/7 [00:00<00:03,  1.91it/s]
# [200]	valid_0's rmse: 1.19516
# Early stopping, best iteration is:
# [101]	valid_0's rmse: 1.18563
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  29%|##8       | 2/7 [00:00<00:02,  2.21it/s][I 2021-05-09 14:55:00,177] Trial 1 finished with value: 1.1970705170640557 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  29%|##8       | 2/7 [00:00<00:02,  2.21it/s]
# Early stopping, best iteration is:
# [96]	valid_0's rmse: 1.19707
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003383 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  43%|####2     | 3/7 [00:01<00:01,  2.24it/s][I 2021-05-09 14:55:00,618] Trial 2 finished with value: 1.1983503811323328 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  43%|####2     | 3/7 [00:01<00:01,  2.24it/s]
# Early stopping, best iteration is:
# [59]	valid_0's rmse: 1.19835
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  57%|#####7    | 4/7 [00:01<00:01,  2.49it/s][I 2021-05-09 14:55:00,952] Trial 3 finished with value: 1.1950001835977906 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  57%|#####7    | 4/7 [00:01<00:01,  2.49it/s]
# Early stopping, best iteration is:
# [82]	valid_0's rmse: 1.195
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  71%|#######1  | 5/7 [00:02<00:00,  2.57it/s][I 2021-05-09 14:55:01,316] Trial 4 finished with value: 1.192938070983803 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  71%|#######1  | 5/7 [00:02<00:00,  2.57it/s]
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 1.19294
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003034 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629:  86%|########5 | 6/7 [00:02<00:00,  2.55it/s][I 2021-05-09 14:55:01,717] Trial 5 finished with value: 1.1927235503594267 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629:  86%|########5 | 6/7 [00:02<00:00,  2.55it/s]
# Early stopping, best iteration is:
# [55]	valid_0's rmse: 1.19272
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 1.185629: 100%|##########| 7/7 [00:02<00:00,  2.61it/s][I 2021-05-09 14:55:02,082] Trial 6 finished with value: 1.1895341966393165 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 1.185628584273061.
# feature_fraction, val_score: 1.185629: 100%|##########| 7/7 [00:02<00:00,  2.47it/s]
# num_leaves, val_score: 1.185629:   0%|          | 0/20 [00:00<?, ?it/s]
# [200]	valid_0's rmse: 1.19811
# Early stopping, best iteration is:
# [107]	valid_0's rmse: 1.18953
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002953 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 1.185629:   5%|5         | 1/20 [00:01<00:23,  1.24s/it][I 2021-05-09 14:55:03,323] Trial 7 finished with value: 1.2180080009284575 and parameters: {'num_leaves': 254}. Best is trial 7 with value: 1.2180080009284575.
# num_leaves, val_score: 1.185629:   5%|5         | 1/20 [00:01<00:23,  1.24s/it]
# Early stopping, best iteration is:
# [41]	valid_0's rmse: 1.21801
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 1.185629:  10%|#         | 2/20 [00:02<00:21,  1.18s/it][I 2021-05-09 14:55:04,470] Trial 8 finished with value: 1.2180080009284575 and parameters: {'num_leaves': 254}. Best is trial 7 with value: 1.2180080009284575.
# num_leaves, val_score: 1.185629:  10%|#         | 2/20 [00:02<00:21,  1.18s/it]
# Early stopping, best iteration is:
# [41]	valid_0's rmse: 1.21801
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  15%|#5        | 3/20 [00:04<00:23,  1.41s/it][I 2021-05-09 14:55:06,146] Trial 9 finished with value: 1.21886825131216 and parameters: {'num_leaves': 209}. Best is trial 7 with value: 1.2180080009284575.
# num_leaves, val_score: 1.185629:  15%|#5        | 3/20 [00:04<00:23,  1.41s/it]
# [200]	valid_0's rmse: 1.21923
# Early stopping, best iteration is:
# [101]	valid_0's rmse: 1.21887
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002011 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  20%|##        | 4/20 [00:05<00:21,  1.35s/it][I 2021-05-09 14:55:07,406] Trial 10 finished with value: 1.2048628724717154 and parameters: {'num_leaves': 169}. Best is trial 10 with value: 1.2048628724717154.
# num_leaves, val_score: 1.185629:  20%|##        | 4/20 [00:05<00:21,  1.35s/it]
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 1.20486
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001989 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.21112
# num_leaves, val_score: 1.185629:  25%|##5       | 5/20 [00:07<00:25,  1.73s/it][I 2021-05-09 14:55:09,799] Trial 11 finished with value: 1.2110803988642618 and parameters: {'num_leaves': 210}. Best is trial 10 with value: 1.2048628724717154.
# num_leaves, val_score: 1.185629:  25%|##5       | 5/20 [00:07<00:25,  1.73s/it]
# Early stopping, best iteration is:
# [199]	valid_0's rmse: 1.21108
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  30%|###       | 6/20 [00:08<00:19,  1.39s/it][I 2021-05-09 14:55:10,546] Trial 12 finished with value: 1.1926585842217534 and parameters: {'num_leaves': 61}. Best is trial 12 with value: 1.1926585842217534.
# num_leaves, val_score: 1.185629:  30%|###       | 6/20 [00:08<00:19,  1.39s/it]
# [200]	valid_0's rmse: 1.19766
# Early stopping, best iteration is:
# [102]	valid_0's rmse: 1.19266
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001979 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 1.185629:  35%|###5      | 7/20 [00:09<00:18,  1.43s/it][I 2021-05-09 14:55:12,056] Trial 13 finished with value: 1.2066083419284497 and parameters: {'num_leaves': 252}. Best is trial 12 with value: 1.1926585842217534.
# num_leaves, val_score: 1.185629:  35%|###5      | 7/20 [00:09<00:18,  1.43s/it]
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 1.20661
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001989 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  40%|####      | 8/20 [00:11<00:16,  1.34s/it][I 2021-05-09 14:55:13,192] Trial 14 finished with value: 1.2127921723334156 and parameters: {'num_leaves': 175}. Best is trial 12 with value: 1.1926585842217534.
# num_leaves, val_score: 1.185629:  40%|####      | 8/20 [00:11<00:16,  1.34s/it]
# Early stopping, best iteration is:
# [69]	valid_0's rmse: 1.21279
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.22023
# num_leaves, val_score: 1.185629:  45%|####5     | 9/20 [00:13<00:18,  1.71s/it][I 2021-05-09 14:55:15,721] Trial 15 finished with value: 1.220158150226817 and parameters: {'num_leaves': 218}. Best is trial 12 with value: 1.1926585842217534.
# num_leaves, val_score: 1.185629:  45%|####5     | 9/20 [00:13<00:18,  1.71s/it]
# Early stopping, best iteration is:
# [242]	valid_0's rmse: 1.22016
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001951 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  50%|#####     | 10/20 [00:14<00:16,  1.60s/it][I 2021-05-09 14:55:17,086] Trial 16 finished with value: 1.2070589454664238 and parameters: {'num_leaves': 191}. Best is trial 12 with value: 1.1926585842217534.
# num_leaves, val_score: 1.185629:  50%|#####     | 10/20 [00:15<00:16,  1.60s/it]
# [200]	valid_0's rmse: 1.20771
# Early stopping, best iteration is:
# [101]	valid_0's rmse: 1.20706
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  55%|#####5    | 11/20 [00:15<00:11,  1.26s/it][I 2021-05-09 14:55:17,578] Trial 17 finished with value: 1.192572631678233 and parameters: {'num_leaves': 41}. Best is trial 17 with value: 1.192572631678233.
# num_leaves, val_score: 1.185629:  55%|#####5    | 11/20 [00:15<00:11,  1.26s/it]
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 1.19257
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  60%|######    | 12/20 [00:15<00:08,  1.00s/it][I 2021-05-09 14:55:17,985] Trial 18 finished with value: 1.1933817516723602 and parameters: {'num_leaves': 44}. Best is trial 17 with value: 1.192572631678233.
# num_leaves, val_score: 1.185629:  60%|######    | 12/20 [00:15<00:08,  1.00s/it]
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 1.19338
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002109 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  65%|######5   | 13/20 [00:16<00:05,  1.18it/s][I 2021-05-09 14:55:18,469] Trial 19 finished with value: 1.194621757053282 and parameters: {'num_leaves': 47}. Best is trial 17 with value: 1.192572631678233.
# num_leaves, val_score: 1.185629:  65%|######5   | 13/20 [00:16<00:05,  1.18it/s]
# Early stopping, best iteration is:
# [59]	valid_0's rmse: 1.19462
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002069 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  70%|#######   | 14/20 [00:17<00:05,  1.19it/s][I 2021-05-09 14:55:19,297] Trial 20 finished with value: 1.1944316166190396 and parameters: {'num_leaves': 89}. Best is trial 17 with value: 1.192572631678233.
# num_leaves, val_score: 1.185629:  70%|#######   | 14/20 [00:17<00:05,  1.19it/s]
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 1.19443
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  75%|#######5  | 15/20 [00:17<00:03,  1.48it/s][I 2021-05-09 14:55:19,588] Trial 21 finished with value: 1.1897897927115544 and parameters: {'num_leaves': 12}. Best is trial 21 with value: 1.1897897927115544.
# num_leaves, val_score: 1.185629:  75%|#######5  | 15/20 [00:17<00:03,  1.48it/s]
# [200]	valid_0's rmse: 1.19849
# Early stopping, best iteration is:
# [102]	valid_0's rmse: 1.18979
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  80%|########  | 16/20 [00:17<00:02,  1.75it/s][I 2021-05-09 14:55:19,920] Trial 22 finished with value: 1.2007095858184258 and parameters: {'num_leaves': 21}. Best is trial 21 with value: 1.1897897927115544.
# num_leaves, val_score: 1.185629:  80%|########  | 16/20 [00:17<00:02,  1.75it/s]
# [200]	valid_0's rmse: 1.21232
# Early stopping, best iteration is:
# [111]	valid_0's rmse: 1.20071
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002278 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.19575
# num_leaves, val_score: 1.185629:  85%|########5 | 17/20 [00:19<00:02,  1.12it/s][I 2021-05-09 14:55:21,563] Trial 23 finished with value: 1.1955732068820757 and parameters: {'num_leaves': 110}. Best is trial 21 with value: 1.1897897927115544.
# num_leaves, val_score: 1.185629:  85%|########5 | 17/20 [00:19<00:02,  1.12it/s]
# Early stopping, best iteration is:
# [208]	valid_0's rmse: 1.19557
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002323 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  90%|######### | 18/20 [00:19<00:01,  1.44it/s][I 2021-05-09 14:55:21,796] Trial 24 finished with value: 1.1897455063949791 and parameters: {'num_leaves': 7}. Best is trial 24 with value: 1.1897455063949791.
# num_leaves, val_score: 1.185629:  90%|######### | 18/20 [00:19<00:01,  1.44it/s]
# [200]	valid_0's rmse: 1.19169
# Early stopping, best iteration is:
# [165]	valid_0's rmse: 1.18975
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 1.185629:  95%|#########5| 19/20 [00:19<00:00,  1.77it/s][I 2021-05-09 14:55:22,061] Trial 25 finished with value: 1.1897897927115544 and parameters: {'num_leaves': 12}. Best is trial 24 with value: 1.1897455063949791.
# num_leaves, val_score: 1.185629:  95%|#########5| 19/20 [00:19<00:00,  1.77it/s]
# [200]	valid_0's rmse: 1.19849
# Early stopping, best iteration is:
# [102]	valid_0's rmse: 1.18979
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001977 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.18622
# num_leaves, val_score: 1.184667: 100%|##########| 20/20 [00:20<00:00,  2.07it/s][I 2021-05-09 14:55:22,349] Trial 26 finished with value: 1.1846671700465876 and parameters: {'num_leaves': 6}. Best is trial 26 with value: 1.1846671700465876.
# num_leaves, val_score: 1.184667: 100%|##########| 20/20 [00:20<00:00,  1.01s/it]
# bagging, val_score: 1.184667:   0%|          | 0/10 [00:00<?, ?it/s]
# Early stopping, best iteration is:
# [245]	valid_0's rmse: 1.18467
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002774 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  10%|#         | 1/10 [00:00<00:02,  3.93it/s][I 2021-05-09 14:55:22,609] Trial 27 finished with value: 1.203710182787563 and parameters: {'bagging_fraction': 0.6610787300188843, 'bagging_freq': 3}. Best is trial 27 with value: 1.203710182787563.
# bagging, val_score: 1.184667:  10%|#         | 1/10 [00:00<00:02,  3.93it/s]
# [200]	valid_0's rmse: 1.20765
# Early stopping, best iteration is:
# [145]	valid_0's rmse: 1.20371
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  20%|##        | 2/10 [00:00<00:02,  3.75it/s][I 2021-05-09 14:55:22,884] Trial 28 finished with value: 1.2019520161796031 and parameters: {'bagging_fraction': 0.579092355830897, 'bagging_freq': 4}. Best is trial 28 with value: 1.2019520161796031.
# bagging, val_score: 1.184667:  20%|##        | 2/10 [00:00<00:02,  3.75it/s]
# [200]	valid_0's rmse: 1.20483
# Early stopping, best iteration is:
# [194]	valid_0's rmse: 1.20195
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002704 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  30%|###       | 3/10 [00:00<00:01,  4.03it/s][I 2021-05-09 14:55:23,111] Trial 29 finished with value: 1.196046766293352 and parameters: {'bagging_fraction': 0.7885162814120321, 'bagging_freq': 6}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  30%|###       | 3/10 [00:00<00:01,  4.03it/s]
# [200]	valid_0's rmse: 1.19734
# Early stopping, best iteration is:
# [111]	valid_0's rmse: 1.19605
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.21263
# bagging, val_score: 1.184667:  40%|####      | 4/10 [00:00<00:01,  4.11it/s][I 2021-05-09 14:55:23,347] Trial 30 finished with value: 1.2091204871280155 and parameters: {'bagging_fraction': 0.450534343531165, 'bagging_freq': 2}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  40%|####      | 4/10 [00:00<00:01,  4.11it/s]
# Early stopping, best iteration is:
# [151]	valid_0's rmse: 1.20912
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001997 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.21518
# bagging, val_score: 1.184667:  50%|#####     | 5/10 [00:01<00:01,  3.84it/s][I 2021-05-09 14:55:23,637] Trial 31 finished with value: 1.2079080090363905 and parameters: {'bagging_fraction': 0.5701036913106803, 'bagging_freq': 5}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  50%|#####     | 5/10 [00:01<00:01,  3.84it/s]
# Early stopping, best iteration is:
# [243]	valid_0's rmse: 1.20791
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.19926
# bagging, val_score: 1.184667:  60%|######    | 6/10 [00:01<00:01,  3.90it/s][I 2021-05-09 14:55:23,886] Trial 32 finished with value: 1.1982815000212337 and parameters: {'bagging_fraction': 0.5428430272823839, 'bagging_freq': 4}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  60%|######    | 6/10 [00:01<00:01,  3.90it/s]
# Early stopping, best iteration is:
# [228]	valid_0's rmse: 1.19828
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002256 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  70%|#######   | 7/10 [00:01<00:00,  3.99it/s][I 2021-05-09 14:55:24,124] Trial 33 finished with value: 1.2019280688621445 and parameters: {'bagging_fraction': 0.7454020008548621, 'bagging_freq': 2}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  70%|#######   | 7/10 [00:01<00:00,  3.99it/s]
# [200]	valid_0's rmse: 1.20461
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 1.20193
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002515 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  80%|########  | 8/10 [00:01<00:00,  4.11it/s][I 2021-05-09 14:55:24,351] Trial 34 finished with value: 1.2017027024974976 and parameters: {'bagging_fraction': 0.639624699580317, 'bagging_freq': 7}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  80%|########  | 8/10 [00:01<00:00,  4.11it/s]
# [200]	valid_0's rmse: 1.20828
# Early stopping, best iteration is:
# [121]	valid_0's rmse: 1.2017
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667:  90%|######### | 9/10 [00:02<00:00,  4.21it/s][I 2021-05-09 14:55:24,576] Trial 35 finished with value: 1.2094125032722922 and parameters: {'bagging_fraction': 0.40630703112017186, 'bagging_freq': 6}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667:  90%|######### | 9/10 [00:02<00:00,  4.21it/s]
# [200]	valid_0's rmse: 1.21626
# Early stopping, best iteration is:
# [154]	valid_0's rmse: 1.20941
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 1.184667: 100%|##########| 10/10 [00:02<00:00,  3.91it/s][I 2021-05-09 14:55:24,872] Trial 36 finished with value: 1.2000898535903013 and parameters: {'bagging_fraction': 0.7997506371719589, 'bagging_freq': 2}. Best is trial 29 with value: 1.196046766293352.
# bagging, val_score: 1.184667: 100%|##########| 10/10 [00:02<00:00,  3.97it/s]
# feature_fraction_stage2, val_score: 1.184667:   0%|          | 0/6 [00:00<?, ?it/s]
# [200]	valid_0's rmse: 1.2022
# Early stopping, best iteration is:
# [180]	valid_0's rmse: 1.20009
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.184667:  17%|#6        | 1/6 [00:00<00:01,  3.01it/s][I 2021-05-09 14:55:25,209] Trial 37 finished with value: 1.19367370167543 and parameters: {'feature_fraction': 0.88}. Best is trial 37 with value: 1.19367370167543.
# feature_fraction_stage2, val_score: 1.184667:  17%|#6        | 1/6 [00:00<00:01,  3.01it/s]
# [200]	valid_0's rmse: 1.19495
# Early stopping, best iteration is:
# [285]	valid_0's rmse: 1.19367
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.184667:  33%|###3      | 2/6 [00:00<00:01,  3.06it/s][I 2021-05-09 14:55:25,532] Trial 38 finished with value: 1.1877180100594036 and parameters: {'feature_fraction': 0.8480000000000001}. Best is trial 38 with value: 1.1877180100594036.
# feature_fraction_stage2, val_score: 1.184667:  33%|###3      | 2/6 [00:00<00:01,  3.06it/s]
# [200]	valid_0's rmse: 1.19001
# Early stopping, best iteration is:
# [284]	valid_0's rmse: 1.18772
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.184667:  50%|#####     | 3/6 [00:00<00:00,  3.55it/s][I 2021-05-09 14:55:25,760] Trial 39 finished with value: 1.1893272978392515 and parameters: {'feature_fraction': 0.8160000000000001}. Best is trial 38 with value: 1.1877180100594036.
# feature_fraction_stage2, val_score: 1.184667:  50%|#####     | 3/6 [00:00<00:00,  3.55it/s]
# [200]	valid_0's rmse: 1.19039
# Early stopping, best iteration is:
# [167]	valid_0's rmse: 1.18933
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.184667:  67%|######6   | 4/6 [00:01<00:00,  3.68it/s][I 2021-05-09 14:55:26,016] Trial 40 finished with value: 1.1864275261446986 and parameters: {'feature_fraction': 0.784}. Best is trial 40 with value: 1.1864275261446986.
# feature_fraction_stage2, val_score: 1.184667:  67%|######6   | 4/6 [00:01<00:00,  3.68it/s]
# [200]	valid_0's rmse: 1.18922
# Early stopping, best iteration is:
# [237]	valid_0's rmse: 1.18643
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002552 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.184667:  83%|########3 | 5/6 [00:01<00:00,  3.58it/s][I 2021-05-09 14:55:26,310] Trial 41 finished with value: 1.1891231008017373 and parameters: {'feature_fraction': 0.7520000000000001}. Best is trial 40 with value: 1.1864275261446986.
# feature_fraction_stage2, val_score: 1.184667:  83%|########3 | 5/6 [00:01<00:00,  3.58it/s]
# [200]	valid_0's rmse: 1.19111
# Early stopping, best iteration is:
# [251]	valid_0's rmse: 1.18912
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001961 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 1.183350: 100%|##########| 6/6 [00:01<00:00,  3.68it/s][I 2021-05-09 14:55:26,566] Trial 42 finished with value: 1.183350409907769 and parameters: {'feature_fraction': 0.7200000000000001}. Best is trial 42 with value: 1.183350409907769.
# feature_fraction_stage2, val_score: 1.183350: 100%|##########| 6/6 [00:01<00:00,  3.54it/s]
# regularization_factors, val_score: 1.183350:   0%|          | 0/20 [00:00<?, ?it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.183350:   5%|5         | 1/20 [00:00<00:05,  3.59it/s][I 2021-05-09 14:55:26,851] Trial 43 finished with value: 1.18335043279643 and parameters: {'lambda_l1': 0.0001329993576619766, 'lambda_l2': 4.085664630734832e-08}. Best is trial 43 with value: 1.18335043279643.
# regularization_factors, val_score: 1.183350:   5%|5         | 1/20 [00:00<00:05,  3.59it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.183350:  10%|#         | 2/20 [00:00<00:05,  3.39it/s][I 2021-05-09 14:55:27,157] Trial 44 finished with value: 1.1893421132401263 and parameters: {'lambda_l1': 0.03288201682284921, 'lambda_l2': 7.863986204552424e-05}. Best is trial 43 with value: 1.18335043279643.
# regularization_factors, val_score: 1.183350:  10%|#         | 2/20 [00:00<00:05,  3.39it/s]
# [200]	valid_0's rmse: 1.1924
# Early stopping, best iteration is:
# [261]	valid_0's rmse: 1.18934
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  15%|#5        | 3/20 [00:00<00:04,  3.47it/s][I 2021-05-09 14:55:27,437] Trial 45 finished with value: 1.1803892760249775 and parameters: {'lambda_l1': 0.4586794368201471, 'lambda_l2': 5.604838559842093}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  15%|#5        | 3/20 [00:00<00:04,  3.47it/s]
# [200]	valid_0's rmse: 1.18172
# Early stopping, best iteration is:
# [210]	valid_0's rmse: 1.18039
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002162 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  20%|##        | 4/20 [00:01<00:04,  3.58it/s][I 2021-05-09 14:55:27,703] Trial 46 finished with value: 1.1861602077792628 and parameters: {'lambda_l1': 0.0054542414440032876, 'lambda_l2': 0.00044715752169044616}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  20%|##        | 4/20 [00:01<00:04,  3.58it/s]
# [200]	valid_0's rmse: 1.18621
# Early stopping, best iteration is:
# [210]	valid_0's rmse: 1.18616
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  25%|##5       | 5/20 [00:01<00:03,  3.80it/s][I 2021-05-09 14:55:27,937] Trial 47 finished with value: 1.183350410782265 and parameters: {'lambda_l1': 4.4593697998082594e-06, 'lambda_l2': 3.395305096451055e-07}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  25%|##5       | 5/20 [00:01<00:03,  3.80it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001995 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  30%|###       | 6/20 [00:01<00:03,  3.74it/s][I 2021-05-09 14:55:28,213] Trial 48 finished with value: 1.1833506260161941 and parameters: {'lambda_l1': 5.772027133753032e-08, 'lambda_l2': 0.000801276943146895}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  30%|###       | 6/20 [00:01<00:03,  3.74it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002022 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  35%|###5      | 7/20 [00:01<00:03,  3.70it/s][I 2021-05-09 14:55:28,489] Trial 49 finished with value: 1.1833504102655348 and parameters: {'lambda_l1': 5.844123416753938e-07, 'lambda_l2': 9.332384754315686e-07}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  35%|###5      | 7/20 [00:01<00:03,  3.70it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  40%|####      | 8/20 [00:02<00:03,  3.54it/s][I 2021-05-09 14:55:28,797] Trial 50 finished with value: 1.1912774548972178 and parameters: {'lambda_l1': 3.877871884847314, 'lambda_l2': 0.029571246339116994}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  40%|####      | 8/20 [00:02<00:03,  3.54it/s]
# [200]	valid_0's rmse: 1.19294
# Early stopping, best iteration is:
# [234]	valid_0's rmse: 1.19128
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  45%|####5     | 9/20 [00:02<00:03,  3.57it/s][I 2021-05-09 14:55:29,071] Trial 51 finished with value: 1.1833504715948644 and parameters: {'lambda_l1': 4.054137413195344e-05, 'lambda_l2': 0.00020273293130577838}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  45%|####5     | 9/20 [00:02<00:03,  3.57it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  50%|#####     | 10/20 [00:02<00:02,  3.56it/s][I 2021-05-09 14:55:29,355] Trial 52 finished with value: 1.1833525687159252 and parameters: {'lambda_l1': 0.001241285010129352, 'lambda_l2': 0.007213977359754204}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  50%|#####     | 10/20 [00:02<00:02,  3.56it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002080 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  55%|#####5    | 11/20 [00:03<00:02,  3.52it/s][I 2021-05-09 14:55:29,646] Trial 53 finished with value: 1.1928630356912422 and parameters: {'lambda_l1': 6.7719157560905465, 'lambda_l2': 4.966018401375571}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  55%|#####5    | 11/20 [00:03<00:02,  3.52it/s]
# [200]	valid_0's rmse: 1.19321
# Early stopping, best iteration is:
# [201]	valid_0's rmse: 1.19286
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  60%|######    | 12/20 [00:03<00:02,  3.68it/s][I 2021-05-09 14:55:29,890] Trial 54 finished with value: 1.183350410467756 and parameters: {'lambda_l1': 3.616934086488409e-08, 'lambda_l2': 2.004790921562558e-06}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  60%|######    | 12/20 [00:03<00:02,  3.68it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  65%|######5   | 13/20 [00:03<00:01,  3.77it/s][I 2021-05-09 14:55:30,140] Trial 55 finished with value: 1.1886353427877994 and parameters: {'lambda_l1': 0.17204493702559398, 'lambda_l2': 9.298075162148155}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  65%|######5   | 13/20 [00:03<00:01,  3.77it/s]
# [200]	valid_0's rmse: 1.18986
# Early stopping, best iteration is:
# [143]	valid_0's rmse: 1.18864
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002988 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  70%|#######   | 14/20 [00:03<00:01,  3.72it/s][I 2021-05-09 14:55:30,418] Trial 56 finished with value: 1.1833504109333703 and parameters: {'lambda_l1': 1.0820619676035787e-06, 'lambda_l2': 3.0852439199488267e-06}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  70%|#######   | 14/20 [00:03<00:01,  3.72it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002617 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  75%|#######5  | 15/20 [00:04<00:01,  3.41it/s][I 2021-05-09 14:55:30,767] Trial 57 finished with value: 1.1884236012400877 and parameters: {'lambda_l1': 0.32043304032380354, 'lambda_l2': 1.1869561338807978e-08}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  75%|#######5  | 15/20 [00:04<00:01,  3.41it/s]
# [200]	valid_0's rmse: 1.19079
# [400]	valid_0's rmse: 1.1934
# Early stopping, best iteration is:
# [317]	valid_0's rmse: 1.18842
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# regularization_factors, val_score: 1.180389:  80%|########  | 16/20 [00:04<00:01,  3.55it/s][I 2021-05-09 14:55:31,021] Trial 58 finished with value: 1.1925210173276863 and parameters: {'lambda_l1': 1.145165029837209e-06, 'lambda_l2': 0.14209046562035432}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  80%|########  | 16/20 [00:04<00:01,  3.55it/s]
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.19403
# Early stopping, best iteration is:
# [165]	valid_0's rmse: 1.19252
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 1.18413
# regularization_factors, val_score: 1.180389:  85%|########5 | 17/20 [00:04<00:00,  3.53it/s][I 2021-05-09 14:55:31,309] Trial 59 finished with value: 1.183350411606511 and parameters: {'lambda_l1': 1.0004296729198071e-08, 'lambda_l2': 6.318222089580103e-06}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  85%|########5 | 17/20 [00:04<00:00,  3.53it/s]
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  90%|######### | 18/20 [00:05<00:00,  3.57it/s][I 2021-05-09 14:55:31,582] Trial 60 finished with value: 1.1878561482173065 and parameters: {'lambda_l1': 1.6724475845547682e-05, 'lambda_l2': 0.5508837502494981}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  90%|######### | 18/20 [00:05<00:00,  3.57it/s]
# [200]	valid_0's rmse: 1.18888
# Early stopping, best iteration is:
# [187]	valid_0's rmse: 1.18786
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389:  95%|#########5| 19/20 [00:05<00:00,  3.69it/s][I 2021-05-09 14:55:31,831] Trial 61 finished with value: 1.1833504099839507 and parameters: {'lambda_l1': 2.347740706153671e-07, 'lambda_l2': 1.1793660586886555e-07}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389:  95%|#########5| 19/20 [00:05<00:00,  3.69it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 1.180389: 100%|##########| 20/20 [00:05<00:00,  3.71it/s][I 2021-05-09 14:55:32,096] Trial 62 finished with value: 1.1833506215445546 and parameters: {'lambda_l1': 0.0012298558309402439, 'lambda_l2': 5.3055093287225e-08}. Best is trial 45 with value: 1.1803892760249775.
# regularization_factors, val_score: 1.180389: 100%|##########| 20/20 [00:05<00:00,  3.62it/s]
# min_data_in_leaf, val_score: 1.180389:   0%|          | 0/5 [00:00<?, ?it/s]
# [200]	valid_0's rmse: 1.18413
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 1.18335
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002450 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.180389:  20%|##        | 1/5 [00:00<00:01,  3.79it/s][I 2021-05-09 14:55:32,365] Trial 63 finished with value: 1.1872322970003317 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 1.1872322970003317.
# min_data_in_leaf, val_score: 1.180389:  20%|##        | 1/5 [00:00<00:01,  3.79it/s]
# [200]	valid_0's rmse: 1.18945
# Early stopping, best iteration is:
# [161]	valid_0's rmse: 1.18723
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.178389:  40%|####      | 2/5 [00:00<00:00,  3.35it/s][I 2021-05-09 14:55:32,686] Trial 64 finished with value: 1.1783886207659657 and parameters: {'min_child_samples': 10}. Best is trial 64 with value: 1.1783886207659657.
# min_data_in_leaf, val_score: 1.178389:  40%|####      | 2/5 [00:00<00:00,  3.35it/s]
# [200]	valid_0's rmse: 1.17976
# Early stopping, best iteration is:
# [262]	valid_0's rmse: 1.17839
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.178389:  60%|######    | 3/5 [00:00<00:00,  3.40it/s][I 2021-05-09 14:55:32,976] Trial 65 finished with value: 1.1801756933045804 and parameters: {'min_child_samples': 25}. Best is trial 64 with value: 1.1783886207659657.
# min_data_in_leaf, val_score: 1.178389:  60%|######    | 3/5 [00:00<00:00,  3.40it/s]
# [200]	valid_0's rmse: 1.1814
# Early stopping, best iteration is:
# [219]	valid_0's rmse: 1.18018
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.178389:  80%|########  | 4/5 [00:01<00:00,  3.39it/s][I 2021-05-09 14:55:33,273] Trial 66 finished with value: 1.1916668444016543 and parameters: {'min_child_samples': 100}. Best is trial 64 with value: 1.1783886207659657.
# min_data_in_leaf, val_score: 1.178389:  80%|########  | 4/5 [00:01<00:00,  3.39it/s]
# [200]	valid_0's rmse: 1.19449
# Early stopping, best iteration is:
# [226]	valid_0's rmse: 1.19167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003243 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7613
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score 0.140148
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 1.178389: 100%|##########| 5/5 [00:01<00:00,  3.48it/s][I 2021-05-09 14:55:33,545] Trial 67 finished with value: 1.1847554379345129 and parameters: {'min_child_samples': 5}. Best is trial 64 with value: 1.1783886207659657.
# min_data_in_leaf, val_score: 1.178389: 100%|##########| 5/5 [00:01<00:00,  3.46it/s]
# [200]	valid_0's rmse: 1.18736
# Early stopping, best iteration is:
# [180]	valid_0's rmse: 1.18476
# goal_deff rmse :  1.2090199685259988

# %%
y_pred_, _ = get_y_pred(y_pred, y_test.values)

pred = pd.DataFrame([y_test.values.tolist(), y_pred_, y_pred]).T
pred.columns =  ['y', 'pred', 'pred2']
pred.sort_values('pred')
pred = pred[pred['y'] != 0]
accuracy = sum(test['H_result'].values == y_pred_) / len(y_test)
accuracy
# Out:
# 0.5950266429840142

# %%
pred
# Out:
#        y  pred     pred2
# 0    3.0   1.0  0.894134
# 1   -1.0   2.0 -1.150202
# 2    1.0   1.0  1.457830
# 3    2.0   0.0 -0.344141
# 4   -1.0   2.0 -1.497411
# 5   -3.0   2.0 -1.400128
# 6   -2.0   0.0 -0.616004
# 7    1.0   1.0  1.001318
# 8    1.0   0.0  0.260765
# 9   -2.0   2.0 -1.074944
# 14   1.0   1.0  2.433364
# 15   2.0   1.0  1.105130
# 16   1.0   1.0  1.215040
# 17  -2.0   2.0 -2.411367
# 20  -1.0   0.0  0.073691
# 22  -1.0   2.0 -0.921307
# 24  -1.0   2.0 -1.449346
# 25   1.0   1.0  0.802534
# 26   1.0   1.0  1.185554
# 28  -1.0   0.0  0.099422
# 29  -2.0   2.0 -1.559488
# 30   1.0   1.0  0.921043
# 31   1.0   0.0  0.416522
# 32  -2.0   2.0 -1.537064
# 33   2.0   0.0 -0.554798
# 34  -2.0   1.0  0.788779
# 35   1.0   0.0  0.366616
# 37   1.0   0.0 -0.234145
# 39  -2.0   0.0  0.669905
# 40  -1.0   1.0  1.354681
# 41   1.0   1.0  0.839322
# 42  -1.0   2.0 -1.272978
# 43   1.0   0.0  0.214650
# 44   1.0   0.0  0.205093
# 46   2.0   1.0  1.133541
# 48   1.0   1.0  1.694494
# 49  -1.0   2.0 -1.063386
# 50   1.0   1.0  1.027667
# 52   1.0   0.0 -0.139354
# 55  -3.0   0.0  0.054769
# 56  -1.0   2.0 -0.839067
# 58   1.0   0.0  0.058931
# 59  -1.0   0.0 -0.510892
# 60  -2.0   0.0  0.025523
# 61  -1.0   0.0 -0.560871
# 62   1.0   1.0  0.803766
# 64  -1.0   2.0 -1.204247
# 65  -1.0   2.0 -1.037085
# 66   1.0   1.0  0.810665
# 67   1.0   0.0  0.120276
# 68   2.0   2.0 -1.251205
# 71   2.0   1.0  1.459879
# 72   1.0   0.0  0.394152
# 73   2.0   1.0  1.093647
# 74   1.0   0.0  0.238800
# 75   1.0   0.0 -0.242568
# 76  -1.0   2.0 -0.950834
# 77  -3.0   2.0 -2.182793
# 78   3.0   1.0  0.881109
# 79   1.0   1.0  0.759375
# 80   1.0   1.0  0.823541
# 82  -2.0   2.0 -0.781002
# 83   1.0   1.0  1.588804
# 84   3.0   0.0  0.371210
# 85  -1.0   1.0  1.232154
# 86   5.0   1.0  2.562740
# 88  -3.0   2.0 -0.741463
# 89   1.0   0.0  0.178081
# 90  -2.0   2.0 -2.486183
# 91   1.0   2.0 -0.903830
# 92   1.0   1.0  0.894891
# 93  -1.0   2.0 -2.259765
# 95   2.0   1.0  1.954595
# 96  -2.0   0.0 -0.229901
# 97  -1.0   0.0 -0.699858
# 98  -1.0   0.0 -0.213296
# 99   1.0   1.0  2.121755
# 100  1.0   0.0  0.361070
# 101  1.0   1.0  1.086656
# 102 -6.0   2.0 -1.873542
# 105  1.0   0.0 -0.045531
# 106  2.0   0.0  0.686054
# 107  2.0   1.0  1.833111
# 109 -3.0   2.0 -1.594979
# 110 -1.0   0.0 -0.305648
# 111  1.0   0.0 -0.068185
# 112  1.0   0.0  0.243153
# 113  2.0   0.0  0.104847
# 114  1.0   0.0  0.206408
# 115  2.0   1.0  1.163665
# 118  1.0   0.0  0.468852
# 119  2.0   1.0  2.740806
# 120  3.0   0.0  0.311058
# 122  1.0   1.0  0.842763
# 123  2.0   1.0  0.902149
# 125  1.0   1.0  1.371930
# 126  2.0   1.0  1.428644
# 127  1.0   0.0  0.360091
# 128  1.0   0.0  0.609322
# 130 -1.0   0.0  0.732017
# 133 -1.0   2.0 -1.656709
# 134  1.0   0.0 -0.171117
# 135 -1.0   0.0  0.566808
# 137 -1.0   0.0 -0.233224
# 138  2.0   0.0  0.433721
# 139 -1.0   2.0 -1.716262
# 140 -2.0   1.0  0.740550
# 141 -1.0   0.0 -0.669771
# 142  1.0   0.0  0.597883
# 143 -1.0   2.0 -1.685597
# 144  3.0   1.0  1.111147
# 145 -2.0   0.0 -0.737691
# 147 -3.0   2.0 -1.546537
# 148  4.0   1.0  2.684721
# 149  4.0   1.0  2.075288
# 150  3.0   1.0  0.942729
# 151 -2.0   2.0 -1.279688
# 152  1.0   0.0  0.718495
# 153 -1.0   1.0  1.196273
# 155 -2.0   2.0 -1.284476
# 156 -2.0   2.0 -1.167115
# 157  1.0   1.0  1.058433
# 163 -2.0   2.0 -1.199488
# 164 -1.0   0.0  0.321105
# 165  1.0   0.0 -0.480293
# 166  1.0   1.0  0.942555
# 167  2.0   1.0  1.074019
# 168  1.0   0.0 -0.078810
# 169 -1.0   2.0 -1.451399
# 170 -1.0   2.0 -1.167395
# 173 -1.0   2.0 -1.773935
# 174  1.0   1.0  2.388378
# 175  3.0   1.0  2.133601
# 176 -2.0   2.0 -2.414119
# 177 -1.0   0.0 -0.640588
# 178  3.0   0.0  0.562283
# 179  3.0   2.0 -0.877094
# 180  1.0   0.0  0.497096
# 185 -1.0   2.0 -1.396619
# 186 -1.0   0.0 -0.340619
# 187 -1.0   1.0  2.496006
# 188 -1.0   2.0 -2.116837
# 189  1.0   1.0  1.424370
# 190 -2.0   2.0 -1.765996
# 191 -2.0   0.0 -0.726941
# 192  2.0   1.0  2.052379
# 194  1.0   1.0  0.835981
# 195  1.0   0.0 -0.175350
# 196  1.0   0.0  0.563403
# 197 -2.0   2.0 -1.062173
# 198  2.0   0.0  0.343140
# 199 -1.0   0.0 -0.470709
# 200 -1.0   2.0 -1.110833
# 201  1.0   0.0  0.166063
# 203 -1.0   0.0  0.303530
# 205  3.0   2.0 -0.767409
# 206 -1.0   0.0  0.325047
# 207 -1.0   2.0 -1.471633
# 208  1.0   0.0 -0.704248
# 209 -2.0   0.0 -0.174958
# 210  1.0   0.0 -0.243974
# 211  3.0   1.0  2.462112
# 212  1.0   1.0  1.119491
# 213 -1.0   2.0 -1.478094
# 214  2.0   1.0  1.287365
# 216 -2.0   2.0 -0.766960
# 217 -1.0   0.0 -0.060253
# 218  3.0   0.0 -0.208555
# 219 -1.0   2.0 -1.079220
# 221  2.0   1.0  1.384279
# 222  3.0   1.0  0.825012
# 224  1.0   1.0  1.147559
# 225 -3.0   2.0 -1.238462
# 227 -1.0   0.0 -0.114958
# 228  1.0   0.0 -0.362968
# 229 -1.0   2.0 -2.784533
# 230 -1.0   0.0  0.408614
# 231  1.0   1.0  1.820416
# 233  1.0   1.0  0.937983
# 234  2.0   1.0  1.964363
# 235  4.0   1.0  2.016928
# 236  1.0   0.0  0.319448
# 237 -1.0   0.0 -0.693616
# 238  2.0   1.0  1.077846
# 240  2.0   1.0  0.935909
# 241  1.0   1.0  1.045853
# 243 -4.0   2.0 -1.262115
# 244 -1.0   2.0 -1.073825
# 245  1.0   0.0 -0.024565
# 248  2.0   1.0  1.720258
# 249  1.0   1.0  0.867651
# 250  2.0   1.0  1.921034
# 251 -1.0   0.0  0.576875
# 252  1.0   0.0  0.392980
# 253 -2.0   2.0 -1.445465
# 254  1.0   2.0 -0.754223
# 255 -4.0   2.0 -1.055744
# 256 -5.0   2.0 -1.491919
# 257  2.0   1.0  1.496538
# 258 -2.0   0.0 -0.609858
# 259  1.0   1.0  1.207872
# 260 -2.0   2.0 -2.010642
# 261 -1.0   0.0  0.006154
# 262  1.0   0.0  0.496856
# 263 -1.0   0.0 -0.407854
# 265  1.0   0.0  0.648334
# 266  1.0   0.0  0.074750
# 267 -2.0   0.0 -0.060850
# 268  1.0   0.0  0.298906
# 269  1.0   1.0  1.254816
# 270 -4.0   2.0 -1.642279
# 272  1.0   0.0  0.337140
# 273  2.0   0.0  0.130017
# 274 -1.0   2.0 -0.832057
# 275 -1.0   0.0 -0.486008
# 277  4.0   1.0  2.192113
# 279  1.0   1.0  1.661054
# 280 -1.0   0.0 -0.499860
# 281 -1.0   2.0 -0.890161
# 282 -1.0   0.0 -0.255082
# 283  3.0   1.0  1.318937
# 284 -6.0   2.0 -2.488880
# 286 -1.0   0.0 -0.178885
# 287  2.0   1.0  1.612806
# 288  1.0   1.0  1.875613
# 290  3.0   1.0  1.742608
# 291 -3.0   2.0 -1.951053
# 292 -2.0   1.0  0.755072
# 293 -1.0   0.0  0.163517
# 295 -3.0   0.0 -0.402834
# 296  1.0   0.0 -0.447353
# 297 -2.0   0.0 -0.380373
# 298 -1.0   0.0 -0.573791
# 299  3.0   1.0  1.124323
# 301 -1.0   2.0 -1.129286
# 302  1.0   0.0 -0.406152
# 304  2.0   1.0  2.407893
# 305  1.0   1.0  1.251040
# 306  1.0   1.0  0.921884
# 307 -1.0   0.0  0.234179
# 308 -1.0   0.0 -0.421553
# 309 -1.0   2.0 -0.980148
# 313 -4.0   2.0 -1.567890
# 314  1.0   1.0  1.564192
# 317 -1.0   2.0 -2.216327
# 319  1.0   1.0  0.994175
# 320  1.0   0.0  0.698418
# 322 -3.0   2.0 -2.240879
# 323  1.0   0.0  0.275465
# 324 -1.0   0.0 -0.739426
# 325  1.0   1.0  1.163846
# 326  8.0   1.0  4.019664
# 327  1.0   0.0  0.567928
# 328  2.0   1.0  0.786730
# 329  2.0   1.0  1.516338
# 330 -2.0   2.0 -1.759360
# 332 -2.0   2.0 -0.844190
# 333 -1.0   2.0 -1.248878
# 334 -1.0   0.0 -0.308154
# 335  1.0   1.0  1.184106
# 336  1.0   1.0  1.646156
# 337 -2.0   2.0 -2.044140
# 338  1.0   0.0  0.355722
# 340 -3.0   0.0 -0.011691
# 341  2.0   1.0  0.906469
# 342  1.0   1.0  0.786158
# 343  2.0   2.0 -1.153000
# 344 -2.0   2.0 -1.251086
# 345 -1.0   2.0 -0.945816
# 348  3.0   0.0  0.714995
# 350 -1.0   0.0  0.185971
# 351  2.0   0.0 -0.014124
# 353  1.0   0.0  0.175736
# 354 -1.0   2.0 -1.574760
# 356  1.0   1.0  1.436760
# 357 -2.0   0.0  0.040069
# 358 -5.0   2.0 -2.285867
# 360  1.0   1.0  1.935949
# 362 -1.0   0.0 -0.303893
# 363  2.0   1.0  0.922554
# 364  1.0   0.0  0.344192
# 365 -1.0   2.0 -1.353551
# 366  1.0   0.0  0.592918
# 367  1.0   1.0  1.076351
# 368 -1.0   0.0  0.098716
# 369  2.0   0.0  0.596743
# 370  2.0   1.0  1.652168
# 372  1.0   0.0 -0.282929
# 373 -1.0   2.0 -0.913280
# 374  4.0   1.0  2.517167
# 376  1.0   1.0  1.802367
# 377  3.0   1.0  2.034594
# 378  1.0   0.0  0.684867
# 380  1.0   0.0 -0.524837
# 381  2.0   1.0  2.054002
# 384  1.0   1.0  1.748356
# 385  2.0   1.0  0.966497
# 386 -3.0   2.0 -1.359444
# 387  2.0   1.0  1.391552
# 388  1.0   1.0  1.356679
# 389  4.0   1.0  2.738371
# 390 -1.0   2.0 -1.940899
# 391  1.0   0.0  0.664779
# 392 -1.0   0.0 -0.379223
# 393  1.0   0.0  0.317708
# 394 -1.0   0.0 -0.338914
# 395 -1.0   0.0 -0.265859
# 396  1.0   0.0 -0.204554
# 397  2.0   0.0  0.607106
# 398 -1.0   0.0 -0.677858
# 399  6.0   1.0  2.166754
# 400  2.0   1.0  1.956299
# 401  1.0   1.0  1.254782
# 402 -2.0   0.0 -0.083921
# 403  2.0   0.0  0.640310
# 406  3.0   1.0  1.106219
# 408 -3.0   2.0 -1.857877
# 409  2.0   1.0  0.750213
# 410  2.0   0.0  0.307633
# 412 -1.0   2.0 -0.972720
# 414  2.0   0.0  0.092154
# 416 -2.0   2.0 -1.410799
# 417  1.0   1.0  1.247673
# 418  2.0   1.0  1.993198
# 419  1.0   1.0  0.983921
# 420 -1.0   0.0  0.281447
# 421 -2.0   2.0 -0.883369
# 422  1.0   0.0  0.245417
# 423 -1.0   2.0 -1.128464
# 424 -1.0   2.0 -1.209989
# 425  2.0   1.0  2.579540
# 426 -1.0   0.0 -0.273879
# 427  1.0   1.0  1.214269
# 428  1.0   0.0 -0.160348
# 429 -3.0   2.0 -1.063615
# 431  2.0   1.0  1.101342
# 432 -2.0   2.0 -1.825030
# 433  1.0   1.0  2.273866
# 435 -1.0   0.0  0.397340
# 436  1.0   0.0  0.523255
# 438  1.0   1.0  0.906715
# 441 -2.0   2.0 -1.389969
# 442  4.0   1.0  1.981785
# 443 -1.0   2.0 -0.984204
# 444  2.0   1.0  1.503778
# 445 -1.0   0.0 -0.242443
# 446 -1.0   0.0  0.730552
# 447  1.0   0.0  0.038846
# 448  1.0   0.0  0.314083
# 449  2.0   1.0  0.806077
# 450  4.0   1.0  2.686260
# 451  1.0   1.0  2.182882
# 453 -1.0   0.0  0.066831
# 454 -1.0   2.0 -1.136215
# 455  1.0   0.0 -0.330461
# 456  2.0   1.0  2.014023
# 457 -5.0   2.0 -2.368920
# 458  1.0   0.0 -0.397785
# 459 -1.0   2.0 -0.934528
# 461 -2.0   2.0 -1.597662
# 462  1.0   1.0  0.844055
# 463 -1.0   2.0 -0.767484
# 464  3.0   1.0  1.768105
# 467  2.0   1.0  1.560630
# 469  1.0   1.0  0.821133
# 470 -2.0   2.0 -0.929765
# 471 -1.0   2.0 -1.702289
# 472  4.0   1.0  2.098058
# 473  2.0   0.0  0.333384
# 474 -1.0   2.0 -1.011447
# 475 -1.0   0.0 -0.476454
# 476 -1.0   0.0  0.110351
# 477  4.0   1.0  3.239354
# 478 -1.0   2.0 -0.755658
# 479 -1.0   0.0 -0.449509
# 480 -3.0   0.0  0.269862
# 481  2.0   0.0  0.086207
# 485  2.0   1.0  1.837946
# 486  1.0   0.0 -0.518735
# 487  1.0   1.0  1.727060
# 488 -1.0   2.0 -1.638820
# 490  1.0   0.0  0.365928
# 491 -1.0   2.0 -1.575377
# 492 -1.0   0.0 -0.191117
# 493  1.0   1.0  2.008342
# 494  3.0   1.0  1.561016
# 495 -4.0   2.0 -0.926681
# 496  1.0   1.0  1.045239
# 497  1.0   1.0  1.509986
# 498 -1.0   0.0  0.363759
# 499 -2.0   2.0 -1.852617
# 500 -1.0   0.0 -0.258437
# 502  3.0   1.0  1.741648
# 505  2.0   1.0  1.012344
# 506 -1.0   2.0 -0.922824
# 508  2.0   1.0  3.187576
# 510  1.0   1.0  1.539765
# 512  1.0   0.0 -0.355295
# 514  2.0   1.0  1.243564
# 515 -3.0   2.0 -1.873875
# 516  2.0   1.0  1.645828
# 518  1.0   0.0  0.555226
# 519 -3.0   2.0 -1.404653
# 520  2.0   1.0  1.247198
# 521 -1.0   1.0  1.079607
# 524 -4.0   2.0 -1.510823
# 525 -1.0   0.0 -0.524677
# 526  1.0   1.0  1.036837
# 529 -4.0   2.0 -2.629863
# 530 -5.0   2.0 -1.990302
# 531  1.0   0.0  0.423216
# 532  1.0   0.0  0.021521
# 534 -2.0   2.0 -1.476008
# 535  1.0   1.0  1.344148
# 536 -1.0   2.0 -2.613474
# 537  1.0   0.0  0.186997
# 539  1.0   2.0 -1.443306
# 540  3.0   1.0  1.092360
# 541  2.0   0.0  0.538366
# 542 -1.0   0.0  0.480321
# 543  1.0   2.0 -1.188961
# 544  2.0   1.0  2.501036
# 545  2.0   1.0  1.563706
# 546  2.0   0.0  0.170004
# 547  1.0   0.0  0.515841
# 548 -1.0   1.0  1.251676
# 549  1.0   1.0  2.246389
# 551  2.0   0.0  0.445248
# 552 -2.0   0.0  0.604832
# 553 -3.0   0.0 -0.484276
# 554  3.0   0.0  0.506991
# 555 -1.0   0.0  0.434644
# 557 -1.0   2.0 -1.513638
# 558 -1.0   0.0 -0.331853
# 559 -1.0   2.0 -1.187018
# 560  1.0   1.0  0.761972
# 561 -1.0   0.0 -0.707034
# 562 -2.0   2.0 -0.781980

# %%
df.loc[df['H_result'] == 0,  'even_flg'] = 0
df.loc[df['H_result'] != 0,  'even_flg'] = 1

# train, val = train_test_split(df, train_size=0.75)
# val, test = train_test_split(val, train_size=0.75)
train = df[df['年月日'] < 20200000]
test = df[df['年月日'] > 20200000]
train, val = train_test_split(train, train_size=0.75)

y_train = train['even_flg']
x_train = train.drop(columns = y_columns + ['even_flg'])
y_val = val['even_flg']
x_val = val.drop(columns = y_columns+ ['even_flg'])
y_test = test['even_flg']
x_test = test.drop(columns = y_columns+ ['even_flg'])

# %%
y_pred, y_pred_proba = fit_binary(x_train, x_val, x_test, y_train, y_val, y_test)
# Out:
# [I 2021-05-09 14:55:34,274] A new study created in memory with name: no-name-03a281a1-3d56-4ba1-b5f0-24062682f096
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]/Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/satouwataru/.pyenv/versions/anaconda3-2020.07/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.571990:  14%|#4        | 1/7 [00:00<00:03,  1.74it/s][I 2021-05-09 14:55:34,854] Trial 0 finished with value: 0.5719900427865342 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.5719900427865342.
# feature_fraction, val_score: 0.571990:  14%|#4        | 1/7 [00:00<00:03,  1.74it/s]
# Early stopping, best iteration is:
# [19]	valid_0's multi_logloss: 0.57199
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002988 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.571400:  29%|##8       | 2/7 [00:01<00:02,  1.85it/s][I 2021-05-09 14:55:35,368] Trial 1 finished with value: 0.5714000314111081 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.5714000314111081.
# feature_fraction, val_score: 0.571400:  29%|##8       | 2/7 [00:01<00:02,  1.85it/s]
# Early stopping, best iteration is:
# [10]	valid_0's multi_logloss: 0.5714
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001809 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.569812:  43%|####2     | 3/7 [00:01<00:01,  2.07it/s][I 2021-05-09 14:55:35,784] Trial 2 finished with value: 0.5698121106128862 and parameters: {'feature_fraction': 0.5}. Best is trial 2 with value: 0.5698121106128862.
# feature_fraction, val_score: 0.569812:  43%|####2     | 3/7 [00:01<00:01,  2.07it/s]
# Early stopping, best iteration is:
# [20]	valid_0's multi_logloss: 0.569812
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002888 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.569812:  57%|#####7    | 4/7 [00:01<00:01,  2.07it/s][I 2021-05-09 14:55:36,266] Trial 3 finished with value: 0.5739536727074767 and parameters: {'feature_fraction': 0.7}. Best is trial 2 with value: 0.5698121106128862.
# feature_fraction, val_score: 0.569812:  57%|#####7    | 4/7 [00:01<00:01,  2.07it/s]
# Early stopping, best iteration is:
# [8]	valid_0's multi_logloss: 0.573954
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.569812:  71%|#######1  | 5/7 [00:02<00:01,  1.97it/s][I 2021-05-09 14:55:36,816] Trial 4 finished with value: 0.5757662675747924 and parameters: {'feature_fraction': 1.0}. Best is trial 2 with value: 0.5698121106128862.
# feature_fraction, val_score: 0.569812:  71%|#######1  | 5/7 [00:02<00:01,  1.97it/s]
# Early stopping, best iteration is:
# [3]	valid_0's multi_logloss: 0.575766
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.566217:  86%|########5 | 6/7 [00:02<00:00,  2.06it/s][I 2021-05-09 14:55:37,256] Trial 5 finished with value: 0.5662165723318922 and parameters: {'feature_fraction': 0.4}. Best is trial 5 with value: 0.5662165723318922.
# feature_fraction, val_score: 0.566217:  86%|########5 | 6/7 [00:02<00:00,  2.06it/s]
# Early stopping, best iteration is:
# [29]	valid_0's multi_logloss: 0.566217
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002276 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# feature_fraction, val_score: 0.566217: 100%|##########| 7/7 [00:03<00:00,  2.06it/s][I 2021-05-09 14:55:37,744] Trial 6 finished with value: 0.5760440172004037 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 5 with value: 0.5662165723318922.
# feature_fraction, val_score: 0.566217: 100%|##########| 7/7 [00:03<00:00,  2.02it/s]
# num_leaves, val_score: 0.566217:   0%|          | 0/20 [00:00<?, ?it/s]
# Early stopping, best iteration is:
# [7]	valid_0's multi_logloss: 0.576044
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:   5%|5         | 1/20 [00:01<00:19,  1.01s/it][I 2021-05-09 14:55:38,757] Trial 7 finished with value: 0.5699455708266725 and parameters: {'num_leaves': 140}. Best is trial 7 with value: 0.5699455708266725.
# num_leaves, val_score: 0.566217:   5%|5         | 1/20 [00:01<00:19,  1.01s/it]
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.569946
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  10%|#         | 2/20 [00:01<00:16,  1.08it/s][I 2021-05-09 14:55:39,629] Trial 8 finished with value: 0.5696726418100283 and parameters: {'num_leaves': 134}. Best is trial 8 with value: 0.5696726418100283.
# num_leaves, val_score: 0.566217:  10%|#         | 2/20 [00:01<00:16,  1.08it/s]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.569673
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001744 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  15%|#5        | 3/20 [00:02<00:13,  1.22it/s][I 2021-05-09 14:55:40,317] Trial 9 finished with value: 0.570429314266025 and parameters: {'num_leaves': 88}. Best is trial 8 with value: 0.5696726418100283.
# num_leaves, val_score: 0.566217:  15%|#5        | 3/20 [00:02<00:13,  1.22it/s]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.570429
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002287 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  20%|##        | 4/20 [00:02<00:10,  1.56it/s][I 2021-05-09 14:55:40,685] Trial 10 finished with value: 0.5674823184852267 and parameters: {'num_leaves': 24}. Best is trial 10 with value: 0.5674823184852267.
# num_leaves, val_score: 0.566217:  20%|##        | 4/20 [00:02<00:10,  1.56it/s]
# Early stopping, best iteration is:
# [20]	valid_0's multi_logloss: 0.567482
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001729 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 0.566217:  25%|##5       | 5/20 [00:04<00:12,  1.16it/s][I 2021-05-09 14:55:41,930] Trial 11 finished with value: 0.5695493488167513 and parameters: {'num_leaves': 256}. Best is trial 10 with value: 0.5674823184852267.
# num_leaves, val_score: 0.566217:  25%|##5       | 5/20 [00:04<00:12,  1.16it/s]
# Early stopping, best iteration is:
# [10]	valid_0's multi_logloss: 0.569549
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  30%|###       | 6/20 [00:05<00:14,  1.01s/it][I 2021-05-09 14:55:43,230] Trial 12 finished with value: 0.5695297546414221 and parameters: {'num_leaves': 236}. Best is trial 10 with value: 0.5674823184852267.
# num_leaves, val_score: 0.566217:  30%|###       | 6/20 [00:05<00:14,  1.01s/it]
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.56953
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  35%|###5      | 7/20 [00:06<00:13,  1.06s/it][I 2021-05-09 14:55:44,388] Trial 13 finished with value: 0.5714908937737441 and parameters: {'num_leaves': 219}. Best is trial 10 with value: 0.5674823184852267.
# num_leaves, val_score: 0.566217:  35%|###5      | 7/20 [00:06<00:13,  1.06s/it]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.571491
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  40%|####      | 8/20 [00:07<00:11,  1.07it/s][I 2021-05-09 14:55:45,047] Trial 14 finished with value: 0.5707952862797036 and parameters: {'num_leaves': 75}. Best is trial 10 with value: 0.5674823184852267.
# num_leaves, val_score: 0.566217:  40%|####      | 8/20 [00:07<00:11,  1.07it/s]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.570795
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002468 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.566217:  45%|####5     | 9/20 [00:07<00:09,  1.18it/s][I 2021-05-09 14:55:45,720] Trial 15 finished with value: 0.5669841207364934 and parameters: {'num_leaves': 95}. Best is trial 15 with value: 0.5669841207364934.
# num_leaves, val_score: 0.566217:  45%|####5     | 9/20 [00:07<00:09,  1.18it/s]
# Early stopping, best iteration is:
# [10]	valid_0's multi_logloss: 0.566984
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  50%|#####     | 10/20 [00:09<00:09,  1.00it/s][I 2021-05-09 14:55:47,045] Trial 16 finished with value: 0.564825276255409 and parameters: {'num_leaves': 231}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  50%|#####     | 10/20 [00:09<00:09,  1.00it/s]
# Early stopping, best iteration is:
# [17]	valid_0's multi_logloss: 0.564825
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001764 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  55%|#####5    | 11/20 [00:10<00:09,  1.03s/it][I 2021-05-09 14:55:48,154] Trial 17 finished with value: 0.5681527710455717 and parameters: {'num_leaves': 196}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  55%|#####5    | 11/20 [00:10<00:09,  1.03s/it]
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.568153
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002089 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  60%|######    | 12/20 [00:11<00:08,  1.06s/it][I 2021-05-09 14:55:49,269] Trial 18 finished with value: 0.5702629804998403 and parameters: {'num_leaves': 178}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  60%|######    | 12/20 [00:11<00:08,  1.06s/it]
# Early stopping, best iteration is:
# [10]	valid_0's multi_logloss: 0.570263
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002290 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  65%|######5   | 13/20 [00:12<00:06,  1.10it/s][I 2021-05-09 14:55:49,836] Trial 19 finished with value: 0.5690458045388647 and parameters: {'num_leaves': 74}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  65%|######5   | 13/20 [00:12<00:06,  1.10it/s]
# Early stopping, best iteration is:
# [13]	valid_0's multi_logloss: 0.569046
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  70%|#######   | 14/20 [00:12<00:04,  1.39it/s][I 2021-05-09 14:55:50,125] Trial 20 finished with value: 0.5693361877323347 and parameters: {'num_leaves': 13}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  70%|#######   | 14/20 [00:12<00:04,  1.39it/s]
# Early stopping, best iteration is:
# [30]	valid_0's multi_logloss: 0.569336
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002217 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  75%|#######5  | 15/20 [00:13<00:04,  1.22it/s][I 2021-05-09 14:55:51,179] Trial 21 finished with value: 0.5679028908956707 and parameters: {'num_leaves': 164}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  75%|#######5  | 15/20 [00:13<00:04,  1.22it/s]
# Early stopping, best iteration is:
# [12]	valid_0's multi_logloss: 0.567903
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  80%|########  | 16/20 [00:14<00:03,  1.22it/s][I 2021-05-09 14:55:52,000] Trial 22 finished with value: 0.5658955146132711 and parameters: {'num_leaves': 115}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  80%|########  | 16/20 [00:14<00:03,  1.22it/s]
# Early stopping, best iteration is:
# [20]	valid_0's multi_logloss: 0.565896
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  85%|########5 | 17/20 [00:15<00:02,  1.21it/s][I 2021-05-09 14:55:52,842] Trial 23 finished with value: 0.5677476119762525 and parameters: {'num_leaves': 109}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  85%|########5 | 17/20 [00:15<00:02,  1.21it/s]
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.567748
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001836 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  90%|######### | 18/20 [00:15<00:01,  1.35it/s][I 2021-05-09 14:55:53,373] Trial 24 finished with value: 0.5671746932061857 and parameters: {'num_leaves': 44}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  90%|######### | 18/20 [00:15<00:01,  1.35it/s]
# Early stopping, best iteration is:
# [30]	valid_0's multi_logloss: 0.567175
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825:  95%|#########5| 19/20 [00:16<00:00,  1.25it/s][I 2021-05-09 14:55:54,309] Trial 25 finished with value: 0.571037040993089 and parameters: {'num_leaves': 154}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825:  95%|#########5| 19/20 [00:16<00:00,  1.25it/s]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.571037
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001028 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# Training until validation scores don't improve for 100 rounds
# num_leaves, val_score: 0.564825: 100%|##########| 20/20 [00:17<00:00,  1.14it/s][I 2021-05-09 14:55:55,363] Trial 26 finished with value: 0.5673616309218018 and parameters: {'num_leaves': 113}. Best is trial 16 with value: 0.564825276255409.
# num_leaves, val_score: 0.564825: 100%|##########| 20/20 [00:17<00:00,  1.14it/s]
# bagging, val_score: 0.564825:   0%|          | 0/10 [00:00<?, ?it/s]
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.567362
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002390 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# bagging, val_score: 0.564825:  10%|#         | 1/10 [00:01<00:09,  1.09s/it][I 2021-05-09 14:55:56,461] Trial 27 finished with value: 0.5739080539990329 and parameters: {'bagging_fraction': 0.653439832957055, 'bagging_freq': 4}. Best is trial 27 with value: 0.5739080539990329.
# bagging, val_score: 0.564825:  10%|#         | 1/10 [00:01<00:09,  1.09s/it]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.573908
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001779 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.564825:  20%|##        | 2/10 [00:02<00:09,  1.18s/it][I 2021-05-09 14:55:57,694] Trial 28 finished with value: 0.5661895131675116 and parameters: {'bagging_fraction': 0.9324151733501547, 'bagging_freq': 2}. Best is trial 28 with value: 0.5661895131675116.
# bagging, val_score: 0.564825:  20%|##        | 2/10 [00:02<00:09,  1.18s/it]
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.56619
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7609
# [LightGBM] [Info] Number of data points in the train set: 6750, number of used features: 85
# [LightGBM] [Info] Start training from score -1.377738
# [LightGBM] [Info] Start training from score -0.290550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# min_data_in_leaf, val_score: 0.564796: 100%|##########| 5/5 [00:05<00:00,  1.17s/it][I 2021-05-09 14:56:42,054] Trial 64 finished with value: 0.5666726644075584 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.5658759181139373.
# min_data_in_leaf, val_score: 0.564796: 100%|##########| 5/5 [00:05<00:00,  1.18s/it]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [11]	valid_0's multi_logloss: 0.566673
# accuracy: 0.7566607460035524

# %%
df1 = pd.DataFrame(y_test.values, columns = ['y_test'])
df2 = pd.DataFrame(y_pred, columns = ['y_pred'])
df3 = pd.DataFrame(y_pred_proba, columns = ['proba_0', 'proba_1'])
pred = pd.concat([df1, df2, df3], axis = 1)
pred[pred['y_test'] == 0]
# Out:
#      y_test  y_pred   proba_0   proba_1
# 6       0.0       1  0.286178  0.713822
# 14      0.0       1  0.153127  0.846873
# 16      0.0       1  0.352963  0.647037
# 19      0.0       1  0.136869  0.863131
# 26      0.0       1  0.284269  0.715731
# 30      0.0       1  0.154894  0.845106
# 31      0.0       1  0.311191  0.688809
# 35      0.0       1  0.190089  0.809911
# 36      0.0       1  0.158986  0.841014
# 37      0.0       1  0.175768  0.824232
# 38      0.0       1  0.221477  0.778523
# 44      0.0       1  0.221565  0.778435
# 45      0.0       1  0.242373  0.757627
# 47      0.0       1  0.223979  0.776021
# 49      0.0       1  0.392273  0.607727
# 54      0.0       1  0.212184  0.787816
# 55      0.0       1  0.223408  0.776592
# 57      0.0       1  0.410617  0.589383
# 64      0.0       1  0.386762  0.613238
# 69      0.0       1  0.310875  0.689125
# 71      0.0       1  0.227564  0.772436
# 72      0.0       1  0.251488  0.748512
# 78      0.0       1  0.213495  0.786505
# 79      0.0       1  0.283664  0.716336
# 81      0.0       1  0.327561  0.672439
# 88      0.0       1  0.173119  0.826881
# 114     0.0       1  0.237494  0.762506
# 116     0.0       1  0.237765  0.762235
# 119     0.0       1  0.320385  0.679615
# 123     0.0       1  0.275653  0.724347
# 124     0.0       1  0.315565  0.684435
# 125     0.0       1  0.338573  0.661427
# 135     0.0       1  0.221358  0.778642
# 138     0.0       1  0.226040  0.773960
# 140     0.0       1  0.115550  0.884450
# 145     0.0       1  0.213288  0.786712
# 146     0.0       1  0.235069  0.764931
# 150     0.0       1  0.215273  0.784727
# 151     0.0       1  0.171745  0.828255
# 160     0.0       1  0.244354  0.755646
# 167     0.0       1  0.150888  0.849112
# 168     0.0       1  0.351803  0.648197
# 170     0.0       1  0.236799  0.763201
# 185     0.0       1  0.164882  0.835118
# 187     0.0       1  0.352490  0.647510
# 195     0.0       1  0.279177  0.720823
# 200     0.0       1  0.225356  0.774644
# 202     0.0       1  0.464597  0.535403
# 210     0.0       1  0.277707  0.722293
# 211     0.0       1  0.182747  0.817253
# 212     0.0       1  0.165377  0.834623
# 213     0.0       1  0.331472  0.668528
# 229     0.0       1  0.104445  0.895555
# 233     0.0       1  0.350883  0.649117
# 238     0.0       1  0.268201  0.731799
# 241     0.0       1  0.264810  0.735190
# 246     0.0       1  0.154433  0.845567
# 248     0.0       1  0.152537  0.847463
# 252     0.0       1  0.486302  0.513698
# 257     0.0       1  0.264835  0.735165
# 264     0.0       1  0.313575  0.686425
# 266     0.0       1  0.291082  0.708918
# 267     0.0       1  0.235602  0.764398
# 281     0.0       1  0.207841  0.792159
# 283     0.0       1  0.227245  0.772755
# 289     0.0       1  0.185839  0.814161
# 293     0.0       1  0.258120  0.741880
# 295     0.0       1  0.407268  0.592732
# 298     0.0       1  0.371093  0.628907
# 299     0.0       1  0.258793  0.741207
# 304     0.0       1  0.139598  0.860402
# 310     0.0       1  0.189523  0.810477
# 313     0.0       1  0.438328  0.561672
# 315     0.0       1  0.171445  0.828555
# 323     0.0       1  0.229408  0.770592
# 330     0.0       1  0.260327  0.739673
# 331     0.0       1  0.198913  0.801087
# 333     0.0       1  0.199971  0.800029
# 335     0.0       1  0.347887  0.652113
# 338     0.0       1  0.174314  0.825686
# 343     0.0       1  0.167055  0.832945
# 346     0.0       1  0.351293  0.648707
# 347     0.0       1  0.371010  0.628990
# 348     0.0       1  0.213807  0.786193
# 349     0.0       1  0.377872  0.622128
# 351     0.0       1  0.141612  0.858388
# 352     0.0       1  0.282808  0.717192
# 354     0.0       1  0.372423  0.627577
# 361     0.0       1  0.204989  0.795011
# 363     0.0       1  0.237020  0.762980
# 372     0.0       1  0.210803  0.789197
# 378     0.0       1  0.240904  0.759096
# 382     0.0       1  0.179500  0.820500
# 391     0.0       1  0.221146  0.778854
# 392     0.0       1  0.261412  0.738588
# 399     0.0       1  0.198246  0.801754
# 404     0.0       1  0.298901  0.701099
# 406     0.0       1  0.177616  0.822384
# 407     0.0       1  0.249039  0.750961
# 413     0.0       1  0.242272  0.757728
# 414     0.0       1  0.258534  0.741466
# 415     0.0       1  0.256342  0.743658
# 420     0.0       1  0.343909  0.656091
# 422     0.0       1  0.237525  0.762475
# 423     0.0       1  0.167912  0.832088
# 425     0.0       1  0.348979  0.651021
# 427     0.0       1  0.303415  0.696585
# 433     0.0       1  0.164758  0.835242
# 436     0.0       1  0.206159  0.793841
# 437     0.0       1  0.289059  0.710941
# 440     0.0       1  0.192510  0.807490
# 447     0.0       1  0.177265  0.822735
# 448     0.0       1  0.096048  0.903952
# 450     0.0       1  0.266420  0.733580
# 464     0.0       1  0.178015  0.821985
# 469     0.0       1  0.164048  0.835952
# 478     0.0       1  0.297908  0.702092
# 480     0.0       1  0.224031  0.775969
# 485     0.0       1  0.118476  0.881524
# 490     0.0       1  0.183513  0.816487
# 493     0.0       1  0.226976  0.773024
# 495     0.0       1  0.218671  0.781329
# 501     0.0       1  0.160096  0.839904
# 504     0.0       1  0.388742  0.611258
# 506     0.0       1  0.309522  0.690478
# 512     0.0       1  0.154581  0.845419
# 518     0.0       1  0.240061  0.759939
# 519     0.0       1  0.270361  0.729639
# 520     0.0       1  0.349947  0.650053
# 521     0.0       1  0.398226  0.601774
# 524     0.0       1  0.332993  0.667007
# 532     0.0       1  0.194138  0.805862
# 533     0.0       1  0.228206  0.771794
# 551     0.0       1  0.227648  0.772352
# 558     0.0       1  0.239817  0.760183
# 559     0.0       1  0.223166  0.776834
# 561     0.0       1  0.355143  0.644857

# %%
y_pred_proba[0]
# Out:
# array([0.16805808, 0.83194192])

# %%
import lightgbm as lgb #LightGBM
# モデルの学習
model = lgb.LGBMClassifier() # モデルのインスタンスの作成
model.fit(x_train, y_train) # モデルの学習

# テストデータの予測クラス (予測クラス(0 or 1)を返す)
y_pred = model.predict(x_test)
# テストデータのクラス予測確率 (各クラスの予測確率 [クラス0の予測確率,クラス1の予測確率] を返す)
y_pred_prob = model.predict_proba(x_test)

# AUC (Area Under the Curve) を計算する
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
auc = metrics.auc(fpr, tpr)
print(auc)

# %%
df1 = pd.DataFrame(y_test.values, columns = ['y_test'])
df2 = pd.DataFrame(y_pred, columns = ['y_pred'])
pred = pd.concat([df1, df2], axis = 1)

# %%
pred[pred['y_test'] == 0]
